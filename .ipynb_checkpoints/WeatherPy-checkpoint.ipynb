# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
MAX_CITIES = None    # change to None for all data
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities[:MAX_CITIES]):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{BASE_URL}?appid={weather_api_key}&q={city.replace(' ', '+')}&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                         "Lat": city_lat, 
                         "Lng": city_lng, 
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         })

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atafu village
# Processing Record 2 of Set 1 | olonkinbyen
# Processing Record 3 of Set 1 | kapuskasing
# Processing Record 4 of Set 1 | kutum
# Processing Record 5 of Set 1 | puerto natales
# Processing Record 6 of Set 1 | yagry
# City not found. Skipping...
# Processing Record 7 of Set 1 | ribadeo
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | calheta
# Processing Record 12 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 1 | kisanga
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | antsiranana
# Processing Record 16 of Set 1 | aasiaat
# Processing Record 17 of Set 1 | tyukhtet
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | edinburgh of the seven seas
# Processing Record 20 of Set 1 | saint-pierre
# Processing Record 21 of Set 1 | sao jose da coroa grande
# Processing Record 22 of Set 1 | chonchi
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | onega
# Processing Record 25 of Set 1 | tazovsky
# Processing Record 26 of Set 1 | dabhol
# Processing Record 27 of Set 1 | blackmans bay
# Processing Record 28 of Set 1 | lihue
# Processing Record 29 of Set 1 | hawaiian paradise park
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 32 of Set 1 | gas city
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | rancheria payau
# Processing Record 35 of Set 1 | prince rupert
# Processing Record 36 of Set 1 | xinzhou
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | lysyye gory
# Processing Record 39 of Set 1 | nambucca heads
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | morondava
# Processing Record 42 of Set 1 | pietermaritzburg
# Processing Record 43 of Set 1 | bilibino
# Processing Record 44 of Set 1 | grytviken
# Processing Record 45 of Set 1 | oyama
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 50 of Set 1 | talnakh
# Processing Record 0 of Set 2 | hovd
# Processing Record 1 of Set 2 | sanya
# Processing Record 2 of Set 2 | mahina
# Processing Record 3 of Set 2 | khowai
# Processing Record 4 of Set 2 | swan hill
# Processing Record 5 of Set 2 | susuman
# Processing Record 6 of Set 2 | bayan nur
# City not found. Skipping...
# Processing Record 7 of Set 2 | beniganj
# Processing Record 8 of Set 2 | anadyr
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | salinopolis
# Processing Record 11 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 12 of Set 2 | al mindak
# Processing Record 13 of Set 2 | el jadid
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | santana
# Processing Record 16 of Set 2 | namibe
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | brokopondo
# Processing Record 20 of Set 2 | qaqortoq
# Processing Record 21 of Set 2 | cova figueira
# Processing Record 22 of Set 2 | saint-denis
# Processing Record 23 of Set 2 | cabedelo
# Processing Record 24 of Set 2 | isafjordur
# Processing Record 25 of Set 2 | papatowai
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | markala
# Processing Record 28 of Set 2 | west island
# Processing Record 29 of Set 2 | palmer
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | howrah
# Processing Record 32 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 2 | richards bay
# Processing Record 34 of Set 2 | les cayes
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | kotabumi
# Processing Record 37 of Set 2 | uturoa
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | north bend
# Processing Record 41 of Set 2 | bokhan
# Processing Record 42 of Set 2 | kenitra
# Processing Record 43 of Set 2 | idanre
# Processing Record 44 of Set 2 | klyuchi
# Processing Record 45 of Set 2 | port mathurin
# Processing Record 46 of Set 2 | saipan
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | axim
# Processing Record 49 of Set 2 | robore
# Processing Record 0 of Set 3 | college
# Processing Record 1 of Set 3 | chibougamau
# Processing Record 2 of Set 3 | bandarbeyla
# Processing Record 3 of Set 3 | grand island
# Processing Record 4 of Set 3 | stony plain
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | la rinconada
# Processing Record 7 of Set 3 | zinder
# Processing Record 8 of Set 3 | stanley
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | noosa heads
# Processing Record 11 of Set 3 | margaret river
# Processing Record 12 of Set 3 | fale old settlement
# Processing Record 13 of Set 3 | westport
# Processing Record 14 of Set 3 | urangan
# Processing Record 15 of Set 3 | crane
# Processing Record 16 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 17 of Set 3 | egilsstadir
# Processing Record 18 of Set 3 | invercargill
# Processing Record 19 of Set 3 | bikaner
# Processing Record 20 of Set 3 | ciacova
# Processing Record 21 of Set 3 | wailua homesteads
# Processing Record 22 of Set 3 | bereeda
# Processing Record 23 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 24 of Set 3 | kirakira
# Processing Record 25 of Set 3 | colonia
# Processing Record 26 of Set 3 | bataipora
# Processing Record 27 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 28 of Set 3 | ilomantsi
# Processing Record 29 of Set 3 | fort bragg
# Processing Record 30 of Set 3 | yelizovo
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | nishinoomote
# Processing Record 33 of Set 3 | ozherel'ye
# Processing Record 34 of Set 3 | sai buri
# Processing Record 35 of Set 3 | bula
# Processing Record 36 of Set 3 | morant bay
# Processing Record 37 of Set 3 | jamaame
# Processing Record 38 of Set 3 | khovd
# Processing Record 39 of Set 3 | benguela
# Processing Record 40 of Set 3 | usinsk
# Processing Record 41 of Set 3 | burutu
# Processing Record 42 of Set 3 | maturin
# Processing Record 43 of Set 3 | cill airne
# Processing Record 44 of Set 3 | rattvik
# City not found. Skipping...
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | sosnovo-ozerskoye
# Processing Record 47 of Set 3 | yellowknife
# Processing Record 48 of Set 3 | dryden
# Processing Record 49 of Set 3 | minab
# Processing Record 0 of Set 4 | umm kaddadah
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | cannonvale
# Processing Record 3 of Set 4 | moyobamba
# Processing Record 4 of Set 4 | hadibu
# Processing Record 5 of Set 4 | amos
# Processing Record 6 of Set 4 | jiayuguan
# Processing Record 7 of Set 4 | calatayud
# Processing Record 8 of Set 4 | tovarkovskiy
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | kopong
# Processing Record 11 of Set 4 | smederevska palanka
# Processing Record 12 of Set 4 | dudinka
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | utrik
# Processing Record 15 of Set 4 | piton saint-leu
# Processing Record 16 of Set 4 | st. john's
# Processing Record 17 of Set 4 | bikenibeu village
# Processing Record 18 of Set 4 | nuuk
# Processing Record 19 of Set 4 | san antonio de pale
# Processing Record 20 of Set 4 | broken hill
# Processing Record 21 of Set 4 | altai
# Processing Record 22 of Set 4 | qamdo
# Processing Record 23 of Set 4 | dalaba
# Processing Record 24 of Set 4 | cuyo
# Processing Record 25 of Set 4 | zheleznogorsk-ilimskiy
# Processing Record 26 of Set 4 | timimoun
# Processing Record 27 of Set 4 | kone
# Processing Record 28 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 29 of Set 4 | witu
# Processing Record 30 of Set 4 | kidal
# Processing Record 31 of Set 4 | pingliang
# Processing Record 32 of Set 4 | port elizabeth
# Processing Record 33 of Set 4 | celestun
# Processing Record 34 of Set 4 | alo
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | nar'yan-mar
# Processing Record 38 of Set 4 | purpe
# Processing Record 39 of Set 4 | iskateley
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | inhambane
# Processing Record 43 of Set 4 | okhotsk
# Processing Record 44 of Set 4 | mahibadhoo
# Processing Record 45 of Set 4 | pacific grove
# Processing Record 46 of Set 4 | kugesi
# Processing Record 47 of Set 4 | faya-largeau
# Processing Record 48 of Set 4 | linton
# Processing Record 49 of Set 4 | la'ie
# Processing Record 0 of Set 5 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 1 of Set 5 | tobruk
# Processing Record 2 of Set 5 | sinabang
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | nyurba
# Processing Record 5 of Set 5 | zhezqazghan
# Processing Record 6 of Set 5 | teknaf
# Processing Record 7 of Set 5 | smithers
# Processing Record 8 of Set 5 | karratha
# Processing Record 9 of Set 5 | gadzhiyevo
# Processing Record 10 of Set 5 | beruniy
# Processing Record 11 of Set 5 | vuktyl
# Processing Record 12 of Set 5 | castillos
# Processing Record 13 of Set 5 | nyala
# Processing Record 14 of Set 5 | mahabe
# City not found. Skipping...
# Processing Record 15 of Set 5 | korla
# Processing Record 16 of Set 5 | preobrazheniye
# Processing Record 17 of Set 5 | qui nhon
# Processing Record 18 of Set 5 | cristalina
# Processing Record 19 of Set 5 | stephenville
# Processing Record 20 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 21 of Set 5 | podporozh'ye
# Processing Record 22 of Set 5 | flying fish cove
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | kingaroy
# Processing Record 25 of Set 5 | isangel
# Processing Record 26 of Set 5 | xinyuan
# Processing Record 27 of Set 5 | dorogobuzh
# Processing Record 28 of Set 5 | luganville
# Processing Record 29 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 30 of Set 5 | nabire
# Processing Record 31 of Set 5 | nadi
# Processing Record 32 of Set 5 | leesburg
# Processing Record 33 of Set 5 | aurangabad
# Processing Record 34 of Set 5 | selfoss
# Processing Record 35 of Set 5 | vorgashor
# Processing Record 36 of Set 5 | st. paul
# Processing Record 37 of Set 5 | aweil
# Processing Record 38 of Set 5 | kyabe
# Processing Record 39 of Set 5 | metlili chaamba
# Processing Record 40 of Set 5 | hai duong
# Processing Record 41 of Set 5 | tadine
# Processing Record 42 of Set 5 | agneaux
# Processing Record 43 of Set 5 | mossel bay
# Processing Record 44 of Set 5 | acapulco de juarez
# Processing Record 45 of Set 5 | granja
# Processing Record 46 of Set 5 | abra pampa
# Processing Record 47 of Set 5 | bologoye
# Processing Record 48 of Set 5 | kemise
# Processing Record 49 of Set 5 | port blair
# Processing Record 0 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 1 of Set 6 | kerikeri
# Processing Record 2 of Set 6 | igrim
# Processing Record 3 of Set 6 | puerto baquerizo moreno
# Processing Record 4 of Set 6 | wahpeton
# Processing Record 5 of Set 6 | port-cartier
# Processing Record 6 of Set 6 | ulladulla
# Processing Record 7 of Set 6 | olyokminsk
# Processing Record 8 of Set 6 | lesnoy
# Processing Record 9 of Set 6 | sioux city
# Processing Record 10 of Set 6 | mount pearl
# Processing Record 11 of Set 6 | tolanaro
# Processing Record 12 of Set 6 | jefferson city
# Processing Record 13 of Set 6 | whakatane
# Processing Record 14 of Set 6 | tangalle
# Processing Record 15 of Set 6 | den burg
# Processing Record 16 of Set 6 | shush
# Processing Record 17 of Set 6 | gourcy
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | romanovo
# Processing Record 20 of Set 6 | vila velha
# Processing Record 21 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 22 of Set 6 | hithadhoo
# Processing Record 23 of Set 6 | keflavik
# Processing Record 24 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 25 of Set 6 | bubaque
# Processing Record 26 of Set 6 | cruzeiro do sul
# Processing Record 27 of Set 6 | san jose de guanipa
# Processing Record 28 of Set 6 | mitrofanovka
# Processing Record 29 of Set 6 | karasburg
# Processing Record 30 of Set 6 | oppdal
# Processing Record 31 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 6 | mount gambier
# Processing Record 33 of Set 6 | manta
# Processing Record 34 of Set 6 | onguday
# Processing Record 35 of Set 6 | leh
# Processing Record 36 of Set 6 | blackwater
# Processing Record 37 of Set 6 | hoxtolgay
# City not found. Skipping...
# Processing Record 38 of Set 6 | mount isa
# Processing Record 39 of Set 6 | zangguy
# City not found. Skipping...
# Processing Record 40 of Set 6 | zeya
# Processing Record 41 of Set 6 | la ronge
# Processing Record 42 of Set 6 | la manga del mar menor
# Processing Record 43 of Set 6 | port saint john's
# Processing Record 44 of Set 6 | acarau
# Processing Record 45 of Set 6 | labytnangi
# Processing Record 46 of Set 6 | ladario
# Processing Record 47 of Set 6 | touros
# Processing Record 48 of Set 6 | katabu
# Processing Record 49 of Set 6 | port shepstone
# Processing Record 0 of Set 7 | la passe
# Processing Record 1 of Set 7 | fagundes
# Processing Record 2 of Set 7 | mar del plata
# Processing Record 3 of Set 7 | zaysan
# Processing Record 4 of Set 7 | galliano
# Processing Record 5 of Set 7 | hammerfest
# Processing Record 6 of Set 7 | berja
# Processing Record 7 of Set 7 | ust-nera
# Processing Record 8 of Set 7 | porto murtinho
# Processing Record 9 of Set 7 | north battleford
# Processing Record 10 of Set 7 | visby
# Processing Record 11 of Set 7 | fortuna
# Processing Record 12 of Set 7 | mundemba
# Processing Record 13 of Set 7 | pul-e khumri
# Processing Record 14 of Set 7 | duba
# Processing Record 15 of Set 7 | moultrie
# Processing Record 16 of Set 7 | ceeldheer
# Processing Record 17 of Set 7 | sale
# Processing Record 18 of Set 7 | sassnitz
# Processing Record 19 of Set 7 | sao joao da barra
# Processing Record 20 of Set 7 | broome
# Processing Record 21 of Set 7 | pucallpa
# Processing Record 22 of Set 7 | togur
# Processing Record 23 of Set 7 | tuzantla
# Processing Record 24 of Set 7 | idri
# Processing Record 25 of Set 7 | washington
# Processing Record 26 of Set 7 | dunedin
# Processing Record 27 of Set 7 | bel ombre
# Processing Record 28 of Set 7 | tsiombe
# Processing Record 29 of Set 7 | shiyan
# Processing Record 30 of Set 7 | camapua
# Processing Record 31 of Set 7 | kosonsoy
# Processing Record 32 of Set 7 | espargos
# City not found. Skipping...
# Processing Record 33 of Set 7 | gorontalo
# Processing Record 34 of Set 7 | kupang
# Processing Record 35 of Set 7 | ramapuram
# Processing Record 36 of Set 7 | itoman
# Processing Record 37 of Set 7 | alice springs
# Processing Record 38 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 39 of Set 7 | east london
# Processing Record 40 of Set 7 | dyatlovo
# Processing Record 41 of Set 7 | constantia
# Processing Record 42 of Set 7 | numan
# Processing Record 43 of Set 7 | camana
# Processing Record 44 of Set 7 | udachny
# Processing Record 45 of Set 7 | bonthe
# Processing Record 46 of Set 7 | pandan
# Processing Record 47 of Set 7 | kangaba
# Processing Record 48 of Set 7 | keetmanshoop
# Processing Record 49 of Set 7 | villa gesell
# Processing Record 0 of Set 8 | grootfontein
# Processing Record 1 of Set 8 | portage la prairie
# Processing Record 2 of Set 8 | extrema
# Processing Record 3 of Set 8 | glencoe
# Processing Record 4 of Set 8 | minas de marcona
# Processing Record 5 of Set 8 | newport
# Processing Record 6 of Set 8 | ar ruways
# Processing Record 7 of Set 8 | cadereyta
# Processing Record 8 of Set 8 | kasoa
# Processing Record 9 of Set 8 | kamloops
# Processing Record 10 of Set 8 | labrador city
# Processing Record 11 of Set 8 | balabac
# Processing Record 12 of Set 8 | doka
# Processing Record 13 of Set 8 | sabang
# Processing Record 14 of Set 8 | quellon
# Processing Record 15 of Set 8 | sur
# Processing Record 16 of Set 8 | karachi
# Processing Record 17 of Set 8 | nagqu
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | i-n-salah
# Processing Record 20 of Set 8 | la sarre
# Processing Record 21 of Set 8 | badger
# Processing Record 22 of Set 8 | hamilton
# Processing Record 23 of Set 8 | novaya igirma
# Processing Record 24 of Set 8 | mincivan
# Processing Record 25 of Set 8 | solhan
# Processing Record 26 of Set 8 | zhongshu
# Processing Record 27 of Set 8 | carnarvon
# Processing Record 28 of Set 8 | charcas
# Processing Record 29 of Set 8 | quila
# Processing Record 30 of Set 8 | tarifa
# Processing Record 31 of Set 8 | solwezi
# Processing Record 32 of Set 8 | newman
# Processing Record 33 of Set 8 | ugoofaaru
# Processing Record 34 of Set 8 | tingo maria
# Processing Record 35 of Set 8 | essaouira
# Processing Record 36 of Set 8 | deqen
# Processing Record 37 of Set 8 | el hadjira
# Processing Record 38 of Set 8 | nova sintra
# Processing Record 39 of Set 8 | fisterra
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | riberalta
# Processing Record 42 of Set 8 | cestos city
# Processing Record 43 of Set 8 | rongelap
# Processing Record 44 of Set 8 | isla mujeres
# Processing Record 45 of Set 8 | vanimo
# Processing Record 46 of Set 8 | rabaul
# Processing Record 47 of Set 8 | sandnessjoen
# Processing Record 48 of Set 8 | ochobo
# Processing Record 49 of Set 8 | katsuren-haebaru
# Processing Record 0 of Set 9 | trairi
# Processing Record 1 of Set 9 | isiolo
# Processing Record 2 of Set 9 | durango
# Processing Record 3 of Set 9 | aitape
# Processing Record 4 of Set 9 | poso
# Processing Record 5 of Set 9 | vilyuchinsk
# Processing Record 6 of Set 9 | villa de soto
# Processing Record 7 of Set 9 | lebu
# Processing Record 8 of Set 9 | ust'-kut
# Processing Record 9 of Set 9 | aswan
# Processing Record 10 of Set 9 | queenstown
# Processing Record 11 of Set 9 | ostrov
# Processing Record 12 of Set 9 | kudahuvadhoo
# Processing Record 13 of Set 9 | kingston
# Processing Record 14 of Set 9 | xianyang
# Processing Record 15 of Set 9 | kruisfontein
# Processing Record 16 of Set 9 | santander jimenez
# Processing Record 17 of Set 9 | imperial
# Processing Record 18 of Set 9 | mammoth lakes
# Processing Record 19 of Set 9 | sinnar
# Processing Record 20 of Set 9 | hotan
# Processing Record 21 of Set 9 | thohoyandou
# Processing Record 22 of Set 9 | sharlyk
# Processing Record 23 of Set 9 | tralee
# Processing Record 24 of Set 9 | kavaratti
# Processing Record 25 of Set 9 | loa janan
# Processing Record 26 of Set 9 | nadym
# Processing Record 27 of Set 9 | kailua-kona
# Processing Record 28 of Set 9 | tindouf
# Processing Record 29 of Set 9 | viedma
# Processing Record 30 of Set 9 | dazhong
# Processing Record 31 of Set 9 | nurota
# Processing Record 32 of Set 9 | saint-francois
# Processing Record 33 of Set 9 | kosh-agach
# Processing Record 34 of Set 9 | sisimiut
# Processing Record 35 of Set 9 | enewetak
# Processing Record 36 of Set 9 | sumbawanga
# Processing Record 37 of Set 9 | las khorey
# Processing Record 38 of Set 9 | luderitz
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | honggang
# Processing Record 41 of Set 9 | tostado
# Processing Record 42 of Set 9 | balaklava
# Processing Record 43 of Set 9 | george town
# Processing Record 44 of Set 9 | nola
# Processing Record 45 of Set 9 | lautoka
# Processing Record 46 of Set 9 | po
# City not found. Skipping...
# Processing Record 47 of Set 9 | strelka
# Processing Record 48 of Set 9 | samsun
# Processing Record 49 of Set 9 | usol'ye
# Processing Record 0 of Set 10 | gebeit
# Processing Record 1 of Set 10 | kerman
# Processing Record 2 of Set 10 | kalemie
# Processing Record 3 of Set 10 | yakeshi
# Processing Record 4 of Set 10 | el porvenir
# Processing Record 5 of Set 10 | bamboo flat
# Processing Record 6 of Set 10 | kochenevo
# Processing Record 7 of Set 10 | khandyga
# Processing Record 8 of Set 10 | neiafu
# Processing Record 9 of Set 10 | san juan del sur
# Processing Record 10 of Set 10 | saint albans
# Processing Record 11 of Set 10 | calasparra
# Processing Record 12 of Set 10 | argo
# Processing Record 13 of Set 10 | khedbrahma
# Processing Record 14 of Set 10 | nassau
# Processing Record 15 of Set 10 | xining
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | palmas
# Processing Record 18 of Set 10 | sheridan
# Processing Record 19 of Set 10 | ad dabbah
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | ta`u
# Processing Record 22 of Set 10 | antofagasta
# Processing Record 23 of Set 10 | port douglas
# Processing Record 24 of Set 10 | lhokseumawe
# Processing Record 25 of Set 10 | haparanda
# Processing Record 26 of Set 10 | miles city
# Processing Record 27 of Set 10 | oranjemund
# Processing Record 28 of Set 10 | conception bay south
# Processing Record 29 of Set 10 | happy valley-goose bay
# Processing Record 30 of Set 10 | labuan
# Processing Record 31 of Set 10 | mejit
# Processing Record 32 of Set 10 | luza
# Processing Record 33 of Set 10 | pandharpur
# Processing Record 34 of Set 10 | arteche
# Processing Record 35 of Set 10 | anna regina
# Processing Record 36 of Set 10 | arkhangel'sk
# Processing Record 37 of Set 10 | capilla de guadalupe
# Processing Record 38 of Set 10 | constitucion
# Processing Record 39 of Set 10 | murray bridge
# Processing Record 40 of Set 10 | terrace
# Processing Record 41 of Set 10 | huicungo
# Processing Record 42 of Set 10 | orange walk
# Processing Record 43 of Set 10 | costa teguise
# City not found. Skipping...
# Processing Record 44 of Set 10 | malvan
# Processing Record 45 of Set 10 | tegueste
# Processing Record 46 of Set 10 | sault ste. marie
# Processing Record 47 of Set 10 | qarazhal
# Processing Record 48 of Set 10 | suva
# Processing Record 49 of Set 10 | brookings
# Processing Record 0 of Set 11 | jurm
# Processing Record 1 of Set 11 | zhaoyuan
# Processing Record 2 of Set 11 | kampene
# Processing Record 3 of Set 11 | pyay
# Processing Record 4 of Set 11 | dongola
# Processing Record 5 of Set 11 | quartz hill
# Processing Record 6 of Set 11 | pangody
# Processing Record 7 of Set 11 | siwa oasis
# Processing Record 8 of Set 11 | gazli
# Processing Record 9 of Set 11 | chengde
# Processing Record 10 of Set 11 | tofol
# Processing Record 11 of Set 11 | ola
# Processing Record 12 of Set 11 | margate
# Processing Record 13 of Set 11 | pariaman
# Processing Record 14 of Set 11 | yaren
# Processing Record 15 of Set 11 | bayji
# Processing Record 16 of Set 11 | longboat key
# Processing Record 17 of Set 11 | darwin
# Processing Record 18 of Set 11 | tekane
# City not found. Skipping...
# Processing Record 19 of Set 11 | kastsyukowka
# Processing Record 20 of Set 11 | cole harbour
# Processing Record 21 of Set 11 | hobyo
# Processing Record 22 of Set 11 | porto novo
# Processing Record 23 of Set 11 | fada
# Processing Record 24 of Set 11 | buka
# Processing Record 25 of Set 11 | vennesla
# Processing Record 26 of Set 11 | weihai
# Processing Record 27 of Set 11 | silapathar
# Processing Record 28 of Set 11 | afaahiti
# Processing Record 29 of Set 11 | ito
# Processing Record 30 of Set 11 | shangri-la
# City not found. Skipping...
# Processing Record 31 of Set 11 | kavarna
# Processing Record 32 of Set 11 | vernon
# Processing Record 33 of Set 11 | verkhniy baskunchak
# Processing Record 34 of Set 11 | cartagena
# Processing Record 35 of Set 11 | remire-montjoly
# Processing Record 36 of Set 11 | sanaa
# Processing Record 37 of Set 11 | emerald
# Processing Record 38 of Set 11 | pointe-noire
# Processing Record 39 of Set 11 | yashkul'
# Processing Record 40 of Set 11 | san andros
# City not found. Skipping...
# Processing Record 41 of Set 11 | callao
# Processing Record 42 of Set 11 | pelplin
# Processing Record 43 of Set 11 | pont rouge
# Processing Record 44 of Set 11 | mezhdurechenskiy
# Processing Record 45 of Set 11 | adrar
# Processing Record 46 of Set 11 | bam
# Processing Record 47 of Set 11 | aldama
# Processing Record 48 of Set 11 | mana
# Processing Record 49 of Set 11 | hasaki
# Processing Record 0 of Set 12 | sena madureira
# Processing Record 1 of Set 12 | saint croix
# Processing Record 2 of Set 12 | nosy varika
# Processing Record 3 of Set 12 | iquitos
# Processing Record 4 of Set 12 | namsos
# Processing Record 5 of Set 12 | catia la mar
# Processing Record 6 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 7 of Set 12 | tarawa
# Processing Record 8 of Set 12 | vorkuta
# Processing Record 9 of Set 12 | oban
# Processing Record 10 of Set 12 | tselinnoye
# Processing Record 11 of Set 12 | singkil
# Processing Record 12 of Set 12 | pathein
# Processing Record 13 of Set 12 | nanded
# City not found. Skipping...
# Processing Record 14 of Set 12 | yeniseysk
# Processing Record 15 of Set 12 | atherton
# Processing Record 16 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 17 of Set 12 | wyszkow
# Processing Record 18 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 19 of Set 12 | nago
# Processing Record 20 of Set 12 | ruidoso
# Processing Record 21 of Set 12 | nouadhibou
# Processing Record 22 of Set 12 | kuanda
# Processing Record 23 of Set 12 | borba
# Processing Record 24 of Set 12 | igarka
# Processing Record 25 of Set 12 | port alberni
# Processing Record 26 of Set 12 | peace river
# Processing Record 27 of Set 12 | nanding
# Processing Record 28 of Set 12 | taibet
# City not found. Skipping...
# Processing Record 29 of Set 12 | polyarnyy
# Processing Record 30 of Set 12 | bishnah
# Processing Record 31 of Set 12 | darhan
# Processing Record 32 of Set 12 | hillsboro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     atafu village  -8.5421 -172.5159     84.27        77          14
# 1       olonkinbyen  70.9221   -8.7187     36.75        99         100
# 2       kapuskasing  49.4169  -82.4331     66.15        40           9
# 3             kutum  14.2000   24.6667     80.51        14          76
# 4    puerto natales -51.7236  -72.4875     41.45        70           0
# ..              ...      ...       ...       ...       ...         ...
# 545         nanding  36.7483  118.0558     64.11        24         100
# 546       polyarnyy  69.1989   33.4478     33.76        98         100
# 547         bishnah  32.6167   74.8667     72.68        40           0
# 548          darhan  49.4867  105.9228     52.95        74         100
# 549       hillsboro  45.5229 -122.9898     65.98        60          75
#
#      Wind Speed Country        Date
# 0         13.85      TK  1683667168
# 1          9.17      SJ  1683667168
# 2          4.83      CA  1683666907
# 3          6.40      SD  1683667170
# 4          9.22      CL  1683667087
# ..          ...     ...         ...
# 545        0.29      CN  1683667320
# 546        4.88      RU  1683667320
# 547        6.20      IN  1683667321
# 548        6.96      MN  1683667321
# 549        4.61      US  1683667321
#
# [550 rows x 9 columns]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   atafu village  -8.5421 -172.5159     84.27        77          14
# 1     olonkinbyen  70.9221   -8.7187     36.75        99         100
# 2     kapuskasing  49.4169  -82.4331     66.15        40           9
# 3           kutum  14.2000   24.6667     80.51        14          76
# 4  puerto natales -51.7236  -72.4875     41.45        70           0
#
#    Wind Speed Country        Date
# 0       13.85      TK  1683667168
# 1        9.17      SJ  1683667168
# 2        4.83      CA  1683666907
# 3        6.40      SD  1683667170
# 4        9.22      CL  1683667087

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         atafu village  -8.5421 -172.5159     84.27        77          14
# 1           olonkinbyen  70.9221   -8.7187     36.75        99         100
# 2           kapuskasing  49.4169  -82.4331     66.15        40           9
# 3                 kutum  14.2000   24.6667     80.51        14          76
# 4        puerto natales -51.7236  -72.4875     41.45        70           0
#
#          Wind Speed Country        Date
# City_ID
# 0             13.85      TK  1683667168
# 1              9.17      SJ  1683667168
# 2              4.83      CA  1683666907
# 3              6.40      SD  1683667170
# 4              9.22      CL  1683667087

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_v_temp = city_data_df.plot.scatter(x='Lat', y='Max Temp', s=10, colormap='viridis',grid=True)
# Incorporate the other graph properties
lat_v_temp.set_xlabel('Latitude')
lat_v_temp.set_ylabel('Temperature (F)')
lat_v_temp.set_title('City Latitude vs. Temperature (2023-05-09)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_v_humidity = city_data_df.plot.scatter(x='Lat', y='Humidity', s=10, colormap='viridis', grid=True)

# Incorporate the other graph properties
lat_v_humidity.set_xlabel('Latitude')
lat_v_humidity.set_ylabel('Humidity (%)')
lat_v_humidity.set_title('City Latitude vs. Humidity (2023-05-09)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_v_cloudiness = city_data_df.plot.scatter(x='Lat', y='Cloudiness', s=10, colormap='viridis', grid=True)


# Incorporate the other graph properties
lat_v_cloudiness.set_xlabel('Latitude')
lat_v_cloudiness.set_ylabel('Cloudiness')
lat_v_cloudiness.set_title('City Latitude vs. Cloudiness (2023-05-09)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_v_wind_speed = city_data_df.plot.scatter(x='Lat', y='Wind Speed', s=10, colormap='viridis', grid=True)

# Incorporate the other graph properties
lat_v_wind_speed.set_xlabel('Latitude')
lat_v_wind_speed.set_ylabel('Wind Speed')
lat_v_wind_speed.set_title('City Latitude vs. Wind Speed (2023-05-09)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_match = city_data_df['Lat']>=0
northern_hemi_df = city_data_df.loc[northern_hemi_match][['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Country','Date']].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  olonkinbyen  70.9221   -8.7187     36.75        99         100        9.17
# 1  kapuskasing  49.4169  -82.4331     66.15        40           9        4.83
# 2        kutum  14.2000   24.6667     80.51        14          76        6.40
# 3      ribadeo  43.5325   -7.0991     50.77        91           4        3.49
# 4       lompoc  34.6391 -120.4579     71.02        67          75       11.01
#
#   Country        Date
# 0      SJ  1683667168
# 1      CA  1683666907
# 2      SD  1683667170
# 3      ES  1683667171
# 4      US  1683667173

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_match = city_data_df['Lat']<0
southern_hemi_df = city_data_df.loc[southern_hemi_match][['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Country','Date']].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   atafu village  -8.5421 -172.5159     84.27        77          14
# 1  puerto natales -51.7236  -72.4875     41.45        70           0
# 2        waitangi -43.9535 -176.5597     60.82        96         100
# 3       adamstown -25.0660 -130.1015     71.04        54          87
# 4         kisanga  -7.4362   37.7034     71.87        83          67
#
#    Wind Speed Country        Date
# 0       13.85      TK  1683667168
# 1        9.22      CL  1683667087
# 2       15.01      NZ  1683667171
# 3       10.33      PN  1683667173
# 4        1.97      TZ  1683667174

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
temperature_northern = northern_hemi_df['Max Temp']

northern_temp_slope, northern_temp_int, northern_temp_r, northern_temp_p, northern_temp_std_err, = linregress(latitude_northern, temperature_northern)
northern_temp_fit = (northern_temp_slope*latitude_northern) + northern_temp_int

northern_temp_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Max Temp', s=10, grid=True, colormap='viridis')
northern_temp_scatter_plot.set_ylabel('Temperature (F)')
northern_temp_scatter_plot.set_xlabel('Latitude')
northern_temp_scatter_plot.set_title('Northern Hemisphere: Temperature vs. Latitude')
plt.plot(latitude_northern, northern_temp_fit, '--', color='r')

# %%
# Linear regression on Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
temperature_southern = southern_hemi_df['Max Temp']

southern_temp_slope, southern_temp_int, southern_temp_r, southern_temp_p, southern_temp_std_err, = linregress(latitude_southern, temperature_southern)
southern_temp_fit = (southern_temp_slope*latitude_southern) + southern_temp_int

southern_temp_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Max Temp', s=10, grid=True, colormap='viridis')
southern_temp_scatter_plot.set_ylabel('Temperature (F)')
southern_temp_scatter_plot.set_xlabel('Latitude')
southern_temp_scatter_plot.set_title('Southern Hemisphere: Temperature vs. Latitude')
plt.plot(latitude_southern, southern_temp_fit, '--', color='r')

# %% [markdown]
# ### Analysis:
# Looking at the two figures, it appears that as one gets closer to the equator, temperatures rise. In the northern hemisphere as latitudes get higher, temperatures go down. In the southern hemisphere, the further south you go (latitudes get further away from zero), the lower the temperatures. For locations near the equator (latitude of zero), temperatures are around 80-90 degrees farenheit, in general. The pearson correlation coefficients for latitude vs. temperature in both the northern and southern hemispheres have absolute values around .8, suggesting a strong relationship between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
humidity_northern = northern_hemi_df['Humidity']

northern_humidity_slope, northern_humidity_int, northern_humidity_r, northern_humidity_p, northern_humidity_std_err, = linregress(latitude_northern, humidity_northern)
northern_humidity_fit = (northern_humidity_slope*latitude_northern) + northern_humidity_int

northern_humidity_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Humidity', s=10, grid=True, colormap='viridis')
northern_humidity_scatter_plot.set_ylabel('Humidity (%)')
northern_humidity_scatter_plot.set_xlabel('Latitude')
northern_humidity_scatter_plot.set_title('Northern Hemisphere: Humidity vs. Latitude')
plt.plot(latitude_northern, northern_humidity_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
humidity_southern = southern_hemi_df['Humidity']

southern_humidity_slope, southern_humidity_int, southern_humidity_r, southern_humidity_p, southern_humidity_std_err, = linregress(latitude_southern, humidity_southern)
southern_humidity_fit = (southern_humidity_slope*latitude_southern) + southern_humidity_int

southern_humidity_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Humidity', s=10, grid=True, colormap='viridis')
southern_humidity_scatter_plot.set_ylabel('Humidity (%)')
southern_humidity_scatter_plot.set_xlabel('Latitude')
southern_humidity_scatter_plot.set_title('Southern Hemisphere: Humidity vs. Latitude')
plt.plot(latitude_southern, southern_humidity_fit, '--', color='r')

# %% [markdown]
# ### Analysis
# In both the southern and northern hemispheres there is not a strong relationship between latitude and humidity. For example, in places with latitudes between 20 and 30 degrees south, we see humidity values around 20% and close to 100%. The linear regression in the southern hemisphere plot is fairly flat, while the linear regression in the northern hemisphere is slightly more angled. In contrast to the relationship between latitude and temperature, the pearson correlation coefficients for both the northern and southern hemispheres (humidity vs. latitude) are below .2, and indicate weak relationships.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
cloudiness_northern = northern_hemi_df['Cloudiness']

northern_cloudiness_slope, northern_cloudiness_int, northern_cloudiness_r, northern_cloudiness_p, northern_cloudiness_std_err, = linregress(latitude_northern, cloudiness_northern)
northern_cloudiness_fit = (northern_cloudiness_slope*latitude_northern) + northern_cloudiness_int

northern_cloudiness_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Cloudiness', s=10, grid=True, colormap='viridis')
northern_cloudiness_scatter_plot.set_ylabel('Cloudiness')
northern_cloudiness_scatter_plot.set_xlabel('Latitude')
northern_cloudiness_scatter_plot.set_title('Northern Hemisphere: Cloudiness vs. Latitude')
plt.plot(latitude_northern, northern_cloudiness_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
cloudiness_southern = southern_hemi_df['Cloudiness']

southern_cloudiness_slope, southern_cloudiness_int, southern_cloudiness_r, southern_cloudiness_p, southern_cloudiness_std_err, = linregress(latitude_southern, cloudiness_southern)
southern_cloudiness_fit = (southern_cloudiness_slope*latitude_southern) + southern_cloudiness_int

southern_cloudiness_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Cloudiness', s=10, grid=True, colormap='viridis')
southern_cloudiness_scatter_plot.set_ylabel('Cloudiness')
southern_cloudiness_scatter_plot.set_xlabel('Latitude')
southern_cloudiness_scatter_plot.set_title('Southern Hemisphere: Cloudiness vs. Latitude')
plt.plot(latitude_southern, southern_cloudiness_fit, '--', color='r')

# %% [markdown]
# **Analysis**
# In the northern hemisphere going further north (further from the equator) shows a slight increase in the level of cloudiness. In the southern hemisphere the relationship is that as you go further north (closer to the equator) cloudiness increases. In both instances the pearson correlation coefficient has an absolute value of less than .2, and is thus the relationship between the two variables very weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
wind_speed_northern = northern_hemi_df['Wind Speed']

northern_wind_speed_slope, northern_wind_speed_int, northern_wind_speed_r, northern_wind_speed_p, northern_wind_speed_std_err, = linregress(latitude_northern, wind_speed_northern)
northern_wind_speed_fit = (northern_wind_speed_slope*latitude_northern) + northern_wind_speed_int

northern_wind_speed_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Wind Speed', s=10, grid=True, colormap='viridis')
northern_wind_speed_scatter_plot.set_ylabel('Wind speed')
northern_wind_speed_scatter_plot.set_xlabel('Latitude')
northern_wind_speed_scatter_plot.set_title('Northern Hemisphere: Wind Speed vs. Latitude')
plt.plot(latitude_northern, northern_wind_speed_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
wind_speed_southern = southern_hemi_df['Wind Speed']

southern_wind_speed_slope, southern_wind_speed_int, southern_wind_speed_r, southern_wind_speed_p, southern_wind_speed_std_err, = linregress(latitude_southern, wind_speed_southern)
southern_wind_speed_fit = (southern_wind_speed_slope*latitude_southern) + southern_wind_speed_int

southern_wind_speed_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Wind Speed', s=10, grid=True, colormap='viridis')
southern_wind_speed_scatter_plot.set_ylabel('Wind speed')
southern_wind_speed_scatter_plot.set_xlabel('Latitude')
southern_wind_speed_scatter_plot.set_title('Southern Hemisphere: Wind Speed vs. Latitude')
plt.plot(latitude_southern, southern_wind_speed_fit, '--', color='r')

# %% [markdown]
# **Analysis**
# In both the northern and southern hemispheres there appear to be slightly negative relationships between latitude and wind speed. In the northern hemisphere going further north (further from the equator) shows a slight decrease in the wind speed. In the southern hemisphere the relationship is that as you go further north (closer to the equator) wind speed decreases. In both instances the pearson correlation coefficient has an absolute value of less than .2, and is thus the relationship between the two variables very weak.
