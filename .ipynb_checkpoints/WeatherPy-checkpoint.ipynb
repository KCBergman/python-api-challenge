# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
MAX_CITIES = None    # change to None for all data
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 584

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities[:MAX_CITIES]):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{BASE_URL}?appid={weather_api_key}&q={city.replace(' ', '+')}&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                         "Lat": city_lat, 
                         "Lng": city_lng, 
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         })

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | al burayqah
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | broome
# Processing Record 5 of Set 1 | mana
# Processing Record 6 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | toliara
# Processing Record 10 of Set 1 | hobbs
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | mount isa
# Processing Record 13 of Set 1 | bikenibeu village
# Processing Record 14 of Set 1 | hovd
# Processing Record 15 of Set 1 | hamilton
# Processing Record 16 of Set 1 | urangan
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | constantia
# Processing Record 19 of Set 1 | macapa
# Processing Record 20 of Set 1 | ust-nera
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | caucete
# Processing Record 23 of Set 1 | ilanskiy
# Processing Record 24 of Set 1 | edinburgh of the seven seas
# Processing Record 25 of Set 1 | hawaiian paradise park
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | kyenjojo
# Processing Record 28 of Set 1 | inarajan village
# Processing Record 29 of Set 1 | peterhead
# Processing Record 30 of Set 1 | dudinka
# Processing Record 31 of Set 1 | gokwe
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | stanley
# Processing Record 35 of Set 1 | beylagan
# City not found. Skipping...
# Processing Record 36 of Set 1 | west island
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | saudarkrokur
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | vorgashor
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | birzebbuga
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | ifatsy
# City not found. Skipping...
# Processing Record 46 of Set 1 | papatowai
# Processing Record 47 of Set 1 | elamanchili
# Processing Record 48 of Set 1 | port mathurin
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | fang
# Processing Record 0 of Set 2 | lihue
# Processing Record 1 of Set 2 | alesund
# Processing Record 2 of Set 2 | banda aceh
# Processing Record 3 of Set 2 | kingston
# Processing Record 4 of Set 2 | waitangi
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | guatrache
# Processing Record 7 of Set 2 | chonchi
# Processing Record 8 of Set 2 | zhetybay
# City not found. Skipping...
# Processing Record 9 of Set 2 | santo antonio
# Processing Record 10 of Set 2 | nuku'alofa
# Processing Record 11 of Set 2 | porkhov
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | iskateley
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 2 | adamstown
# Processing Record 17 of Set 2 | kirakira
# Processing Record 18 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | nuuk
# Processing Record 21 of Set 2 | fort wellington
# Processing Record 22 of Set 2 | praia da vitoria
# Processing Record 23 of Set 2 | margaret river
# Processing Record 24 of Set 2 | mersing
# Processing Record 25 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 26 of Set 2 | flying fish cove
# Processing Record 27 of Set 2 | meadow lake
# Processing Record 28 of Set 2 | brisas de zicatela
# Processing Record 29 of Set 2 | alexandria
# Processing Record 30 of Set 2 | queenstown
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | greymouth
# Processing Record 33 of Set 2 | paita
# Processing Record 34 of Set 2 | labrador city
# Processing Record 35 of Set 2 | daru
# Processing Record 36 of Set 2 | ibshaway
# Processing Record 37 of Set 2 | severo-yeniseyskiy
# Processing Record 38 of Set 2 | santa luzia
# Processing Record 39 of Set 2 | erenhot
# Processing Record 40 of Set 2 | st. john's
# Processing Record 41 of Set 2 | saipan
# Processing Record 42 of Set 2 | zaozersk
# Processing Record 43 of Set 2 | dibba al-hisn
# Processing Record 44 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 2 | college
# Processing Record 46 of Set 2 | zouerate
# Processing Record 47 of Set 2 | page
# Processing Record 48 of Set 2 | saint-louis
# Processing Record 49 of Set 2 | hadibu
# Processing Record 0 of Set 3 | al kharj
# Processing Record 1 of Set 3 | zaragoza
# Processing Record 2 of Set 3 | mount vernon
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | sarykemer
# Processing Record 5 of Set 3 | blackmans bay
# Processing Record 6 of Set 3 | yicheng
# Processing Record 7 of Set 3 | cine
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | seabra
# Processing Record 10 of Set 3 | punta arenas
# Processing Record 11 of Set 3 | atafu village
# Processing Record 12 of Set 3 | uturoa
# Processing Record 13 of Set 3 | bilibino
# Processing Record 14 of Set 3 | qaqortoq
# Processing Record 15 of Set 3 | acapulco de juarez
# Processing Record 16 of Set 3 | anton lizardo
# Processing Record 17 of Set 3 | enewetak
# Processing Record 18 of Set 3 | north bend
# Processing Record 19 of Set 3 | rabo de peixe
# Processing Record 20 of Set 3 | egilsstadir
# Processing Record 21 of Set 3 | newman
# Processing Record 22 of Set 3 | lauro de freitas
# Processing Record 23 of Set 3 | fale old settlement
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | bodo
# Processing Record 26 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 27 of Set 3 | san luis de la loma
# Processing Record 28 of Set 3 | poli
# Processing Record 29 of Set 3 | rancho palos verdes
# Processing Record 30 of Set 3 | ulaangom
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | goundam
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | oleszyce
# Processing Record 35 of Set 3 | udachny
# Processing Record 36 of Set 3 | polyarnyy
# Processing Record 37 of Set 3 | hami
# Processing Record 38 of Set 3 | an nuhud
# Processing Record 39 of Set 3 | khadan khak
# Processing Record 40 of Set 3 | grand-lahou
# Processing Record 41 of Set 3 | qarqaraly
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | olonkinbyen
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | madalena
# Processing Record 46 of Set 3 | palikir - national government center
# Processing Record 47 of Set 3 | natal
# Processing Record 48 of Set 3 | noumea
# Processing Record 49 of Set 3 | olutanga
# Processing Record 0 of Set 4 | antalaha
# Processing Record 1 of Set 4 | bonthe
# Processing Record 2 of Set 4 | wailua homesteads
# Processing Record 3 of Set 4 | jalai nur
# Processing Record 4 of Set 4 | jesus maria garza
# City not found. Skipping...
# Processing Record 5 of Set 4 | sofifi
# City not found. Skipping...
# Processing Record 6 of Set 4 | vilyuchinsk
# Processing Record 7 of Set 4 | ixtapa
# Processing Record 8 of Set 4 | khonsa
# Processing Record 9 of Set 4 | kromy
# Processing Record 10 of Set 4 | kannur
# Processing Record 11 of Set 4 | santa cruz
# Processing Record 12 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 4 | santa vitoria do palmar
# Processing Record 14 of Set 4 | celestun
# Processing Record 15 of Set 4 | shache
# Processing Record 16 of Set 4 | kenai
# Processing Record 17 of Set 4 | saint-paul-les-dax
# Processing Record 18 of Set 4 | campbell river
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | pamandzi
# Processing Record 21 of Set 4 | sinabang
# Processing Record 22 of Set 4 | baracoa
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | kalmunai
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | kourou
# Processing Record 27 of Set 4 | keflavik
# Processing Record 28 of Set 4 | isafjordur
# Processing Record 29 of Set 4 | ostersund
# Processing Record 30 of Set 4 | riverside
# Processing Record 31 of Set 4 | dem'yanovo
# Processing Record 32 of Set 4 | prince rupert
# Processing Record 33 of Set 4 | nadi
# Processing Record 34 of Set 4 | baiyin
# Processing Record 35 of Set 4 | nemuro
# Processing Record 36 of Set 4 | kiffa
# Processing Record 37 of Set 4 | tolanaro
# Processing Record 38 of Set 4 | palora
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | karratha
# Processing Record 41 of Set 4 | hoxtolgay
# City not found. Skipping...
# Processing Record 42 of Set 4 | bamboo flat
# Processing Record 43 of Set 4 | juneau
# Processing Record 44 of Set 4 | irymple
# Processing Record 45 of Set 4 | whitehorse
# Processing Record 46 of Set 4 | qamdo
# Processing Record 47 of Set 4 | menongue
# Processing Record 48 of Set 4 | nanao
# Processing Record 49 of Set 4 | stornoway
# Processing Record 0 of Set 5 | roses
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 2 of Set 5 | brentwood estates
# Processing Record 3 of Set 5 | rikaze
# Processing Record 4 of Set 5 | belo sur tsiribihina
# Processing Record 5 of Set 5 | itamaraju
# Processing Record 6 of Set 5 | chandbali
# Processing Record 7 of Set 5 | hammerfest
# Processing Record 8 of Set 5 | vila franca do campo
# Processing Record 9 of Set 5 | sangmelima
# Processing Record 10 of Set 5 | arendal
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | bintulu
# Processing Record 13 of Set 5 | camabatela
# Processing Record 14 of Set 5 | kisoro
# Processing Record 15 of Set 5 | el granada
# Processing Record 16 of Set 5 | port lincoln
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | al 'aziziyah
# Processing Record 19 of Set 5 | klyuchi
# Processing Record 20 of Set 5 | slubice
# Processing Record 21 of Set 5 | tafresh
# Processing Record 22 of Set 5 | nelson
# Processing Record 23 of Set 5 | sinjar
# Processing Record 24 of Set 5 | banlung
# Processing Record 25 of Set 5 | sisimiut
# Processing Record 26 of Set 5 | big park
# Processing Record 27 of Set 5 | oriximina
# Processing Record 28 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 29 of Set 5 | freetown
# Processing Record 30 of Set 5 | taiynsha
# Processing Record 31 of Set 5 | metu
# Processing Record 32 of Set 5 | bardai
# Processing Record 33 of Set 5 | manggar
# Processing Record 34 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 35 of Set 5 | galesong
# Processing Record 36 of Set 5 | mili
# Processing Record 37 of Set 5 | aykhal
# Processing Record 38 of Set 5 | howrah
# Processing Record 39 of Set 5 | sitka
# Processing Record 40 of Set 5 | xicotencatl
# Processing Record 41 of Set 5 | horta
# Processing Record 42 of Set 5 | sheridan
# Processing Record 43 of Set 5 | nizhneudinsk
# Processing Record 44 of Set 5 | minot
# Processing Record 45 of Set 5 | ringkobing
# Processing Record 46 of Set 5 | mugia
# Processing Record 47 of Set 5 | badger
# Processing Record 48 of Set 5 | moroto
# Processing Record 49 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 0 of Set 6 | amuntai
# Processing Record 1 of Set 6 | huarmey
# Processing Record 2 of Set 6 | kaa-khem
# Processing Record 3 of Set 6 | mostaganem
# Processing Record 4 of Set 6 | san antonio de pale
# Processing Record 5 of Set 6 | ad dawadimi
# Processing Record 6 of Set 6 | invercargill
# Processing Record 7 of Set 6 | merizo village
# Processing Record 8 of Set 6 | floriano
# Processing Record 9 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 10 of Set 6 | at taraf
# Processing Record 11 of Set 6 | utrik
# Processing Record 12 of Set 6 | porto novo
# Processing Record 13 of Set 6 | woolgoolga
# Processing Record 14 of Set 6 | grande prairie
# Processing Record 15 of Set 6 | waterford
# Processing Record 16 of Set 6 | namibe
# Processing Record 17 of Set 6 | yangambi
# Processing Record 18 of Set 6 | konarka
# Processing Record 19 of Set 6 | cromwell
# Processing Record 20 of Set 6 | nepanagar
# Processing Record 21 of Set 6 | maua
# Processing Record 22 of Set 6 | el calafate
# Processing Record 23 of Set 6 | new norfolk
# Processing Record 24 of Set 6 | tazovsky
# Processing Record 25 of Set 6 | lebu
# Processing Record 26 of Set 6 | puerto baquerizo moreno
# Processing Record 27 of Set 6 | vadso
# Processing Record 28 of Set 6 | tidjikja
# Processing Record 29 of Set 6 | binbrook
# Processing Record 30 of Set 6 | weno
# Processing Record 31 of Set 6 | kovdor
# Processing Record 32 of Set 6 | minas de marcona
# Processing Record 33 of Set 6 | badiyah
# Processing Record 34 of Set 6 | susuman
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | saldanha
# Processing Record 37 of Set 6 | okondja
# Processing Record 38 of Set 6 | haiku-pauwela
# Processing Record 39 of Set 6 | nar'yan-mar
# Processing Record 40 of Set 6 | tippi
# Processing Record 41 of Set 6 | sishilichengzi
# City not found. Skipping...
# Processing Record 42 of Set 6 | uray
# Processing Record 43 of Set 6 | myrzakent
# Processing Record 44 of Set 6 | manturovo
# Processing Record 45 of Set 6 | birnin kudu
# Processing Record 46 of Set 6 | tsiombe
# Processing Record 47 of Set 6 | xilin hot
# Processing Record 48 of Set 6 | arvayheer
# Processing Record 49 of Set 6 | rawlins
# Processing Record 0 of Set 7 | marondera
# Processing Record 1 of Set 7 | chinchilla
# Processing Record 2 of Set 7 | kapa'a
# Processing Record 3 of Set 7 | arkhangel'sk
# Processing Record 4 of Set 7 | manokwari
# Processing Record 5 of Set 7 | visby
# Processing Record 6 of Set 7 | marsaskala
# City not found. Skipping...
# Processing Record 7 of Set 7 | mogadishu
# Processing Record 8 of Set 7 | liberal
# Processing Record 9 of Set 7 | tura
# Processing Record 10 of Set 7 | brookings
# Processing Record 11 of Set 7 | diboll
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | nikolayevsk-on-amure
# Processing Record 14 of Set 7 | bethanie
# Processing Record 15 of Set 7 | kapuskasing
# Processing Record 16 of Set 7 | martuk
# Processing Record 17 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 18 of Set 7 | margate
# Processing Record 19 of Set 7 | maragogi
# Processing Record 20 of Set 7 | akureyri
# Processing Record 21 of Set 7 | likisa
# Processing Record 22 of Set 7 | yuzhno-kurilsk
# Processing Record 23 of Set 7 | guiyang
# Processing Record 24 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 25 of Set 7 | crucecita
# Processing Record 26 of Set 7 | kasaragod
# Processing Record 27 of Set 7 | novomoskovs'k
# Processing Record 28 of Set 7 | kassala
# Processing Record 29 of Set 7 | anadyr
# Processing Record 30 of Set 7 | alice springs
# Processing Record 31 of Set 7 | mar del plata
# Processing Record 32 of Set 7 | colchani
# Processing Record 33 of Set 7 | parabel'
# Processing Record 34 of Set 7 | rifle
# Processing Record 35 of Set 7 | laojunmiao
# Processing Record 36 of Set 7 | pathein
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | west bay
# Processing Record 39 of Set 7 | city of balikpapan
# Processing Record 40 of Set 7 | katsuura
# Processing Record 41 of Set 7 | birjand
# Processing Record 42 of Set 7 | vorkuta
# Processing Record 43 of Set 7 | talnakh
# Processing Record 44 of Set 7 | abohar
# Processing Record 45 of Set 7 | lautoka
# Processing Record 46 of Set 7 | reyes
# Processing Record 47 of Set 7 | sao jose da coroa grande
# Processing Record 48 of Set 7 | smithers
# Processing Record 49 of Set 7 | bamyan
# Processing Record 0 of Set 8 | puerto real
# Processing Record 1 of Set 8 | aasiaat
# Processing Record 2 of Set 8 | gebeit
# Processing Record 3 of Set 8 | callao
# Processing Record 4 of Set 8 | mata-utu
# Processing Record 5 of Set 8 | afgooye
# Processing Record 6 of Set 8 | si chiang mai
# Processing Record 7 of Set 8 | nabire
# Processing Record 8 of Set 8 | samsun
# Processing Record 9 of Set 8 | nanakuli
# Processing Record 10 of Set 8 | baringo
# Processing Record 11 of Set 8 | oodweyne
# Processing Record 12 of Set 8 | mariental
# Processing Record 13 of Set 8 | ebon
# Processing Record 14 of Set 8 | chegdomyn
# Processing Record 15 of Set 8 | benavente
# Processing Record 16 of Set 8 | yambio
# Processing Record 17 of Set 8 | barcelos
# Processing Record 18 of Set 8 | paracuru
# Processing Record 19 of Set 8 | campoverde
# Processing Record 20 of Set 8 | maxcanu
# Processing Record 21 of Set 8 | krizevci
# Processing Record 22 of Set 8 | chibougamau
# Processing Record 23 of Set 8 | mejit
# Processing Record 24 of Set 8 | pong nam ron
# Processing Record 25 of Set 8 | al mahwit
# Processing Record 26 of Set 8 | rongelap
# Processing Record 27 of Set 8 | comodoro rivadavia
# Processing Record 28 of Set 8 | najran
# Processing Record 29 of Set 8 | sona
# Processing Record 30 of Set 8 | soe
# Processing Record 31 of Set 8 | dryden
# Processing Record 32 of Set 8 | bodaybo
# Processing Record 33 of Set 8 | pemangkat
# Processing Record 34 of Set 8 | smara
# Processing Record 35 of Set 8 | turpan
# Processing Record 36 of Set 8 | fort st. john
# Processing Record 37 of Set 8 | kailua-kona
# Processing Record 38 of Set 8 | rabigh
# Processing Record 39 of Set 8 | port-vila
# Processing Record 40 of Set 8 | fort mcmurray
# Processing Record 41 of Set 8 | labytnangi
# Processing Record 42 of Set 8 | launceston
# Processing Record 43 of Set 8 | qalat
# Processing Record 44 of Set 8 | paka
# Processing Record 45 of Set 8 | lata
# Processing Record 46 of Set 8 | galliano
# Processing Record 47 of Set 8 | yaren
# Processing Record 48 of Set 8 | zag
# Processing Record 49 of Set 8 | tabas
# Processing Record 0 of Set 9 | wuchuan
# Processing Record 1 of Set 9 | saint-philippe
# Processing Record 2 of Set 9 | ain beni mathar
# City not found. Skipping...
# Processing Record 3 of Set 9 | tadine
# Processing Record 4 of Set 9 | zvishavane
# Processing Record 5 of Set 9 | shitanjing
# Processing Record 6 of Set 9 | kone
# Processing Record 7 of Set 9 | causeni
# Processing Record 8 of Set 9 | farasan
# Processing Record 9 of Set 9 | remire-montjoly
# Processing Record 10 of Set 9 | antsiranana
# Processing Record 11 of Set 9 | baker city
# Processing Record 12 of Set 9 | jinchang
# Processing Record 13 of Set 9 | novobelokatay
# Processing Record 14 of Set 9 | miracema do tocantins
# Processing Record 15 of Set 9 | bandar
# Processing Record 16 of Set 9 | sidney
# Processing Record 17 of Set 9 | raduzhnyy
# Processing Record 18 of Set 9 | moyale
# Processing Record 19 of Set 9 | walvis bay
# Processing Record 20 of Set 9 | newcastle west
# Processing Record 21 of Set 9 | banamba
# Processing Record 22 of Set 9 | kabinda
# Processing Record 23 of Set 9 | port macquarie
# Processing Record 24 of Set 9 | isabela
# Processing Record 25 of Set 9 | nouadhibou
# Processing Record 26 of Set 9 | al-`ula
# City not found. Skipping...
# Processing Record 27 of Set 9 | port augusta
# Processing Record 28 of Set 9 | harstad
# Processing Record 29 of Set 9 | impfondo
# Processing Record 30 of Set 9 | morehead city
# Processing Record 31 of Set 9 | camocim
# Processing Record 32 of Set 9 | khandyga
# Processing Record 33 of Set 9 | rehoboth
# Processing Record 34 of Set 9 | as sulayyil
# Processing Record 35 of Set 9 | nicoya
# Processing Record 36 of Set 9 | kharakvasla
# Processing Record 37 of Set 9 | nago
# Processing Record 38 of Set 9 | koulamoutou
# Processing Record 39 of Set 9 | raja
# Processing Record 40 of Set 9 | beltran
# Processing Record 41 of Set 9 | berdigestyakh
# Processing Record 42 of Set 9 | gay
# Processing Record 43 of Set 9 | moab
# Processing Record 44 of Set 9 | papao
# Processing Record 45 of Set 9 | kupiskis
# Processing Record 46 of Set 9 | sassandra
# Processing Record 47 of Set 9 | ouesso
# Processing Record 48 of Set 9 | colonia
# Processing Record 49 of Set 9 | taoudenni
# Processing Record 0 of Set 10 | puerto armuelles
# Processing Record 1 of Set 10 | mount gambier
# Processing Record 2 of Set 10 | gadzhiyevo
# Processing Record 3 of Set 10 | labis
# Processing Record 4 of Set 10 | cadale
# Processing Record 5 of Set 10 | portland
# Processing Record 6 of Set 10 | ketchikan
# Processing Record 7 of Set 10 | kattivakkam
# Processing Record 8 of Set 10 | al kharijah
# Processing Record 9 of Set 10 | san luis
# Processing Record 10 of Set 10 | whangarei
# Processing Record 11 of Set 10 | happy valley-goose bay
# Processing Record 12 of Set 10 | pervomayskiy
# Processing Record 13 of Set 10 | al hazm
# Processing Record 14 of Set 10 | hassi messaoud
# Processing Record 15 of Set 10 | carnarvon
# Processing Record 16 of Set 10 | sonoita
# Processing Record 17 of Set 10 | bubaque
# Processing Record 18 of Set 10 | oranjemund
# Processing Record 19 of Set 10 | qujing
# Processing Record 20 of Set 10 | kijang
# Processing Record 21 of Set 10 | poronaysk
# Processing Record 22 of Set 10 | chibuto
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | vernon
# Processing Record 25 of Set 10 | nema
# Processing Record 26 of Set 10 | pedernales
# Processing Record 27 of Set 10 | hithadhoo
# Processing Record 28 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 29 of Set 10 | isangel
# Processing Record 30 of Set 10 | bhamo
# Processing Record 31 of Set 10 | adam
# Processing Record 32 of Set 10 | tralee
# Processing Record 33 of Set 10 | buka
# Processing Record 34 of Set 10 | colac
# Processing Record 35 of Set 10 | hirara
# Processing Record 36 of Set 10 | dipayal
# Processing Record 37 of Set 10 | alcacer do sal
# Processing Record 38 of Set 10 | geraldton
# Processing Record 39 of Set 10 | bargara
# City not found. Skipping...
# Processing Record 40 of Set 10 | haimen
# Processing Record 41 of Set 10 | stow
# Processing Record 42 of Set 10 | paramonga
# Processing Record 43 of Set 10 | kenora
# Processing Record 44 of Set 10 | vilyuysk
# Processing Record 45 of Set 10 | lauttasaari
# Processing Record 46 of Set 10 | cabedelo
# Processing Record 47 of Set 10 | chokwe
# Processing Record 48 of Set 10 | vrangel'
# Processing Record 49 of Set 10 | norfolk
# Processing Record 0 of Set 11 | cheremushki
# Processing Record 1 of Set 11 | concepcion
# Processing Record 2 of Set 11 | kununurra
# Processing Record 3 of Set 11 | la'ie
# Processing Record 4 of Set 11 | kem'
# Processing Record 5 of Set 11 | antsohihy
# Processing Record 6 of Set 11 | perechyn
# Processing Record 7 of Set 11 | hongqiao
# Processing Record 8 of Set 11 | grabow
# Processing Record 9 of Set 11 | kudahuvadhoo
# Processing Record 10 of Set 11 | fisterra
# Processing Record 11 of Set 11 | crane
# Processing Record 12 of Set 11 | tazacorte
# Processing Record 13 of Set 11 | aonla
# Processing Record 14 of Set 11 | kunszentmarton
# Processing Record 15 of Set 11 | jiaozhou
# Processing Record 16 of Set 11 | oltinko'l
# Processing Record 17 of Set 11 | selfoss
# Processing Record 18 of Set 11 | puerto aysen
# Processing Record 19 of Set 11 | urucui
# Processing Record 20 of Set 11 | srivardhan
# Processing Record 21 of Set 11 | igbeti
# Processing Record 22 of Set 11 | shajiang
# Processing Record 23 of Set 11 | iquique
# Processing Record 24 of Set 11 | miyang
# Processing Record 25 of Set 11 | qal'at bishah
# City not found. Skipping...
# Processing Record 26 of Set 11 | toledo
# Processing Record 27 of Set 11 | chaman
# Processing Record 28 of Set 11 | narra
# Processing Record 29 of Set 11 | hastings
# Processing Record 30 of Set 11 | svetlyy
# Processing Record 31 of Set 11 | pasuquin
# Processing Record 32 of Set 11 | urengoy
# Processing Record 33 of Set 11 | panshan
# Processing Record 34 of Set 11 | fillmore
# Processing Record 35 of Set 11 | vuktyl
# Processing Record 36 of Set 11 | island harbour
# Processing Record 37 of Set 11 | ilhabela
# Processing Record 38 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 39 of Set 11 | pointe michel
# Processing Record 40 of Set 11 | pyin oo lwin
# Processing Record 41 of Set 11 | tianpeng
# Processing Record 42 of Set 11 | vysokiy
# Processing Record 43 of Set 11 | serebryanyye prudy
# Processing Record 44 of Set 11 | karak city
# Processing Record 45 of Set 11 | manay
# Processing Record 46 of Set 11 | naracoorte
# Processing Record 47 of Set 11 | balikpapan
# Processing Record 48 of Set 11 | trairi
# Processing Record 49 of Set 11 | middelburg
# Processing Record 0 of Set 12 | mhamid
# Processing Record 1 of Set 12 | ytrebygda
# Processing Record 2 of Set 12 | manaure
# Processing Record 3 of Set 12 | caernarfon
# Processing Record 4 of Set 12 | malabrigo
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | achinsk
# Processing Record 7 of Set 12 | vershino-darasunskiy
# Processing Record 8 of Set 12 | mount pearl
# Processing Record 9 of Set 12 | mityana
# Processing Record 10 of Set 12 | saint-francois
# Processing Record 11 of Set 12 | rio tuba
# Processing Record 12 of Set 12 | road town
# Processing Record 13 of Set 12 | broken hill
# Processing Record 14 of Set 12 | blitar
# Processing Record 15 of Set 12 | saguenay
# Processing Record 16 of Set 12 | greenville
# Processing Record 17 of Set 12 | jatibonico
# Processing Record 18 of Set 12 | patrocinio
# Processing Record 19 of Set 12 | bayan nur
# City not found. Skipping...
# Processing Record 20 of Set 12 | taghazout
# Processing Record 21 of Set 12 | zhezqazghan
# Processing Record 22 of Set 12 | kalymnos
# Processing Record 23 of Set 12 | malango
# Processing Record 24 of Set 12 | witu
# Processing Record 25 of Set 12 | aoulef
# Processing Record 26 of Set 12 | nepalgunj
# Processing Record 27 of Set 12 | scituate
# Processing Record 28 of Set 12 | kalevala
# Processing Record 29 of Set 12 | kavaratti
# Processing Record 30 of Set 12 | alto barinas
# Processing Record 31 of Set 12 | cabezon de la sal
# Processing Record 32 of Set 12 | tarakan
# Processing Record 33 of Set 12 | klaksvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       puerto natales -51.7236  -72.4875     49.98        98          99
# 1          al burayqah  30.4062   19.5739     64.45        75           1
# 2            grytviken -54.2811  -36.5092     36.43        88          66
# 3               broome  42.2506  -75.8330     60.71        59          75
# 4                 mana   5.6592  -53.7767     77.29        89         100
# ..                 ...      ...       ...       ...       ...         ...
# 552          kavaratti  10.5669   72.6420     83.03        71          94
# 553       alto barinas   8.5931  -70.2261     93.27        43          99
# 554  cabezon de la sal  43.3089   -4.2302     59.83        69          52
# 555            tarakan   3.3000  117.6333     78.30        94          40
# 556           klaksvik  62.2266   -6.5890     45.52        90         100
#
#      Wind Speed Country        Date
# 0          3.13      CL  1683323768
# 1         17.52      LY  1683323768
# 2         12.12      GS  1683323768
# 3         11.99      US  1683323768
# 4         10.80      GF  1683323769
# ..          ...     ...         ...
# 552        7.23      IN  1683323898
# 553        4.09      VE  1683323899
# 554        2.82      ES  1683323899
# 555        8.05      ID  1683323899
# 556       25.59      FO  1683323899
#
# [557 rows x 9 columns]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto natales -51.7236 -72.4875     49.98        98          99
# 1     al burayqah  30.4062  19.5739     64.45        75           1
# 2       grytviken -54.2811 -36.5092     36.43        88          66
# 3          broome  42.2506 -75.8330     60.71        59          75
# 4            mana   5.6592 -53.7767     77.29        89         100
#
#    Wind Speed Country        Date
# 0        3.13      CL  1683323768
# 1       17.52      LY  1683323768
# 2       12.12      GS  1683323768
# 3       11.99      US  1683323768
# 4       10.80      GF  1683323769

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236 -72.4875     49.98        98          99
# 1           al burayqah  30.4062  19.5739     64.45        75           1
# 2             grytviken -54.2811 -36.5092     36.43        88          66
# 3                broome  42.2506 -75.8330     60.71        59          75
# 4                  mana   5.6592 -53.7767     77.29        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.13      CL  1683323768
# 1             17.52      LY  1683323768
# 2             12.12      GS  1683323768
# 3             11.99      US  1683323768
# 4             10.80      GF  1683323769

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_v_temp = city_data_df.plot.scatter(x='Lat', y='Max Temp', s=10, colormap='viridis',grid=True)
# Incorporate the other graph properties
lat_v_temp.set_xlabel('Latitude')
lat_v_temp.set_ylabel('Temperature (F)')
lat_v_temp.set_title('City Latitude vs. Temperature (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_v_humidity = city_data_df.plot.scatter(x='Lat', y='Humidity', s=10, colormap='viridis', grid=True)

# Incorporate the other graph properties
lat_v_humidity.set_xlabel('Latitude')
lat_v_humidity.set_ylabel('Humidity (%)')
lat_v_humidity.set_title('City Latitude vs. Humidity (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_v_cloudiness = city_data_df.plot.scatter(x='Lat', y='Cloudiness', s=10, colormap='viridis', grid=True)


# Incorporate the other graph properties
lat_v_cloudiness.set_xlabel('Latitude')
lat_v_cloudiness.set_ylabel('Cloudiness')
lat_v_cloudiness.set_title('City Latitude vs. Cloudiness (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
lat_v_wind_speed = city_data_df.plot.scatter(x='Lat', y='Wind Speed', s=10, colormap='viridis', grid=True)

# Incorporate the other graph properties
lat_v_wind_speed.set_xlabel('Latitude')
lat_v_wind_speed.set_ylabel('Wind Speed')
lat_v_wind_speed.set_title('City Latitude vs. Wind Speed (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#y = (m*x) + b

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_match = city_data_df['Lat']>=0
northern_hemi_df = city_data_df.loc[northern_hemi_match][['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Country','Date']].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        al burayqah  30.4062   19.5739     64.45        75           1
# 1             broome  42.2506  -75.8330     60.71        59          75
# 2               mana   5.6592  -53.7767     77.29        89         100
# 3              hobbs  32.7026 -103.1360     88.81         6           0
# 4  bikenibeu village   1.3673  173.1241     87.76        70          20
#
#    Wind Speed Country        Date
# 0       17.52      LY  1683323768
# 1       11.99      US  1683323768
# 2       10.80      GF  1683323769
# 3       20.71      US  1683323770
# 4        6.91      KI  1683323585

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_match = city_data_df['Lat']<0
southern_hemi_df = city_data_df.loc[southern_hemi_match][['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Country','Date']].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     puerto natales -51.7236 -72.4875     49.98        98          99
# 1          grytviken -54.2811 -36.5092     36.43        88          66
# 2  port-aux-francais -49.3500  70.2167     43.81        78          91
# 3           luderitz -26.6481  15.1594     56.84        79          51
# 4            toliara -23.3500  43.6667     69.60        84          31
#
#    Wind Speed Country        Date
# 0        3.13      CL  1683323768
# 1       12.12      GS  1683323768
# 2       28.27      TF  1683323561
# 3        9.64     NaN  1683323769
# 4        4.81      MG  1683323769

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
temperature_northern = northern_hemi_df['Max Temp']

northern_temp_slope, northern_temp_int, northern_temp_r, northern_temp_p, northern_temp_std_err, = linregress(latitude_northern, temperature_northern)
northern_temp_fit = (northern_temp_slope*latitude_northern) + northern_temp_int

northern_temp_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Max Temp', s=10, grid=True, colormap='viridis')
northern_temp_scatter_plot.set_ylabel('Temperature (F)')
northern_temp_scatter_plot.set_xlabel('Latitude')
northern_temp_scatter_plot.set_title('Northern Hemisphere: Temperature vs. Latitude')
plt.plot(latitude_northern, northern_temp_fit, '--', color='r')

# %%
# Linear regression on Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
temperature_southern = southern_hemi_df['Max Temp']

southern_temp_slope, southern_temp_int, southern_temp_r, southern_temp_p, southern_temp_std_err, = linregress(latitude_southern, temperature_southern)
southern_temp_fit = (southern_temp_slope*latitude_southern) + southern_temp_int

southern_temp_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Max Temp', s=10, grid=True, colormap='viridis')
southern_temp_scatter_plot.set_ylabel('Temperature (F)')
southern_temp_scatter_plot.set_xlabel('Latitude')
southern_temp_scatter_plot.set_title('Southern Hemisphere: Temperature vs. Latitude')
plt.plot(latitude_southern, southern_temp_fit, '--', color='r')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
humidity_northern = northern_hemi_df['Humidity']

northern_humidity_slope, northern_humidity_int, northern_humidity_r, northern_humidity_p, northern_humidity_std_err, = linregress(latitude_northern, humidity_northern)
northern_humidity_fit = (northern_humidity_slope*latitude_northern) + northern_humidity_int

northern_humidity_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Humidity', s=10, grid=True, colormap='viridis')
northern_humidity_scatter_plot.set_ylabel('Humidity (%)')
northern_humidity_scatter_plot.set_xlabel('Latitude')
northern_humidity_scatter_plot.set_title('Northern Hemisphere: Humidity vs. Latitude')
plt.plot(latitude_northern, northern_humidity_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
humidity_southern = southern_hemi_df['Humidity']

southern_humidity_slope, southern_humidity_int, southern_humidity_r, southern_humidity_p, southern_humidity_std_err, = linregress(latitude_southern, humidity_southern)
southern_humidity_fit = (southern_humidity_slope*latitude_southern) + southern_humidity_int

southern_humidity_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Humidity', s=10, grid=True, colormap='viridis')
southern_humidity_scatter_plot.set_ylabel('Humidity (%)')
southern_humidity_scatter_plot.set_xlabel('Latitude')
southern_humidity_scatter_plot.set_title('Southern Hemisphere: Humidity vs. Latitude')
plt.plot(latitude_southern, southern_humidity_fit, '--', color='r')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
cloudiness_northern = northern_hemi_df['Cloudiness']

northern_cloudiness_slope, northern_cloudiness_int, northern_cloudiness_r, northern_cloudiness_p, northern_cloudiness_std_err, = linregress(latitude_northern, cloudiness_northern)
northern_cloudiness_fit = (northern_cloudiness_slope*latitude_northern) + northern_cloudiness_int

northern_cloudiness_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Cloudiness', s=10, grid=True, colormap='viridis')
northern_cloudiness_scatter_plot.set_ylabel('Cloudiness')
northern_cloudiness_scatter_plot.set_xlabel('Latitude')
northern_cloudiness_scatter_plot.set_title('Northern Hemisphere: Cloudiness vs. Latitude')
plt.plot(latitude_northern, northern_cloudiness_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
cloudiness_southern = southern_hemi_df['Cloudiness']

southern_cloudiness_slope, southern_cloudiness_int, southern_cloudiness_r, southern_cloudiness_p, southern_cloudiness_std_err, = linregress(latitude_southern, cloudiness_southern)
southern_cloudiness_fit = (southern_cloudiness_slope*latitude_southern) + southern_cloudiness_int

southern_cloudiness_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Cloudiness', s=10, grid=True, colormap='viridis')
southern_cloudiness_scatter_plot.set_ylabel('Cloudiness')
southern_cloudiness_scatter_plot.set_xlabel('Latitude')
southern_cloudiness_scatter_plot.set_title('Southern Hemisphere: Cloudiness vs. Latitude')
plt.plot(latitude_southern, southern_cloudiness_fit, '--', color='r')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
wind_speed_northern = northern_hemi_df['Wind Speed']

northern_wind_speed_slope, northern_wind_speed_int, northern_wind_speed_r, northern_wind_speed_p, northern_wind_speed_std_err, = linregress(latitude_northern, wind_speed_northern)
northern_wind_speed_fit = (northern_wind_speed_slope*latitude_northern) + northern_wind_speed_int

northern_wind_speed_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Wind Speed', s=10, grid=True, colormap='viridis')
northern_wind_speed_scatter_plot.set_ylabel('Wind speed')
northern_wind_speed_scatter_plot.set_xlabel('Latitude')
northern_wind_speed_scatter_plot.set_title('Northern Hemisphere: Wind Speed vs. Latitude')
plt.plot(latitude_northern, northern_wind_speed_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
wind_speed_southern = southern_hemi_df['Wind Speed']

southern_wind_speed_slope, southern_wind_speed_int, southern_wind_speed_r, southern_wind_speed_p, southern_wind_speed_std_err, = linregress(latitude_southern, wind_speed_southern)
southern_wind_speed_fit = (southern_wind_speed_slope*latitude_southern) + southern_wind_speed_int

southern_wind_speed_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Wind Speed', s=10, grid=True, colormap='viridis')
southern_wind_speed_scatter_plot.set_ylabel('Wind speed')
southern_wind_speed_scatter_plot.set_xlabel('Latitude')
southern_wind_speed_scatter_plot.set_title('Southern Hemisphere: Wind Speed vs. Latitude')
plt.plot(latitude_southern, southern_wind_speed_fit, '--', color='r')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
