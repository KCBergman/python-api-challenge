# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
MAX_CITIES = None    # change to None for all data
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 567

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities[:MAX_CITIES]):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{BASE_URL}?appid={weather_api_key}&q={city.replace(' ', '+')}&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                         "Lat": city_lat, 
                         "Lng": city_lng, 
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         })

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | kavaratti
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 1 | kailua-kona
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | susuman
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | tomatlan
# Processing Record 13 of Set 1 | saint-pierre
# Processing Record 14 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 1 | st. john's
# Processing Record 16 of Set 1 | iskateley
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | galliano
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | puerto baquerizo moreno
# Processing Record 21 of Set 1 | utrik
# Processing Record 22 of Set 1 | west island
# Processing Record 23 of Set 1 | port lincoln
# Processing Record 24 of Set 1 | newman
# Processing Record 25 of Set 1 | atafu village
# Processing Record 26 of Set 1 | sittwe
# Processing Record 27 of Set 1 | nar'yan-mar
# Processing Record 28 of Set 1 | olyokminsk
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | aasiaat
# Processing Record 36 of Set 1 | archidona
# Processing Record 37 of Set 1 | bella union
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | hurricane
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | la'ie
# Processing Record 42 of Set 1 | broken hill
# Processing Record 43 of Set 1 | whitehorse
# Processing Record 44 of Set 1 | hami
# Processing Record 45 of Set 1 | natal
# Processing Record 46 of Set 1 | adamstown
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | thunder bay
# Processing Record 49 of Set 1 | arkhangel'sk
# Processing Record 50 of Set 1 | 'izbat al burj
# City not found. Skipping...
# Processing Record 0 of Set 2 | cabo san lucas
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | edinburgh of the seven seas
# Processing Record 3 of Set 2 | klyuchi
# Processing Record 4 of Set 2 | madang
# Processing Record 5 of Set 2 | kerikeri
# Processing Record 6 of Set 2 | concepcion
# Processing Record 7 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 2 | happy valley-goose bay
# Processing Record 9 of Set 2 | palmer
# Processing Record 10 of Set 2 | diphu
# Processing Record 11 of Set 2 | tamandare
# Processing Record 12 of Set 2 | ust-nera
# Processing Record 13 of Set 2 | guankou
# Processing Record 14 of Set 2 | yuzhno-kurilsk
# Processing Record 15 of Set 2 | kimberley
# Processing Record 16 of Set 2 | college
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | alaghsas
# Processing Record 19 of Set 2 | richards bay
# Processing Record 20 of Set 2 | 'ali sabieh
# Processing Record 21 of Set 2 | blackmans bay
# Processing Record 22 of Set 2 | laguna
# Processing Record 23 of Set 2 | maumere
# Processing Record 24 of Set 2 | cururupu
# Processing Record 25 of Set 2 | margaret river
# Processing Record 26 of Set 2 | bubaque
# Processing Record 27 of Set 2 | halifax
# Processing Record 28 of Set 2 | dubbo
# Processing Record 29 of Set 2 | beira
# Processing Record 30 of Set 2 | goondiwindi
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 33 of Set 2 | invercargill
# Processing Record 34 of Set 2 | anadyr
# Processing Record 35 of Set 2 | pestravka
# Processing Record 36 of Set 2 | maceio
# Processing Record 37 of Set 2 | lagunas
# Processing Record 38 of Set 2 | acarau
# Processing Record 39 of Set 2 | port mathurin
# Processing Record 40 of Set 2 | lata
# Processing Record 41 of Set 2 | kara-balta
# Processing Record 42 of Set 2 | alice springs
# Processing Record 43 of Set 2 | oranjemund
# Processing Record 44 of Set 2 | tidjikja
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | papatowai
# Processing Record 47 of Set 2 | katsuren-haebaru
# Processing Record 48 of Set 2 | lihue
# Processing Record 49 of Set 2 | constantia
# Processing Record 0 of Set 3 | nova sintra
# Processing Record 1 of Set 3 | vorgashor
# Processing Record 2 of Set 3 | udachny
# Processing Record 3 of Set 3 | haapajarvi
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | tolanaro
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | sharypovo
# Processing Record 8 of Set 3 | stanley
# Processing Record 9 of Set 3 | tonghae
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | haiku-pauwela
# Processing Record 12 of Set 3 | hawaiian paradise park
# Processing Record 13 of Set 3 | tabou
# Processing Record 14 of Set 3 | la ronge
# Processing Record 15 of Set 3 | trubchevsk
# Processing Record 16 of Set 3 | shangri-la
# City not found. Skipping...
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | revda
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | rexburg
# Processing Record 21 of Set 3 | saipan
# Processing Record 22 of Set 3 | puerto natales
# Processing Record 23 of Set 3 | port saint john's
# Processing Record 24 of Set 3 | castillos
# Processing Record 25 of Set 3 | tangalle
# Processing Record 26 of Set 3 | jackson
# Processing Record 27 of Set 3 | kone
# Processing Record 28 of Set 3 | mount isa
# Processing Record 29 of Set 3 | khovd
# Processing Record 30 of Set 3 | zaozersk
# Processing Record 31 of Set 3 | nemuro
# Processing Record 32 of Set 3 | nanfeng
# Processing Record 33 of Set 3 | opuwo
# Processing Record 34 of Set 3 | isafjordur
# Processing Record 35 of Set 3 | al muwayh
# Processing Record 36 of Set 3 | ugoofaaru
# Processing Record 37 of Set 3 | kachug
# Processing Record 38 of Set 3 | ujae
# Processing Record 39 of Set 3 | badger
# Processing Record 40 of Set 3 | plettenberg bay
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | harper
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | pakruojis
# Processing Record 45 of Set 3 | saint-francois
# Processing Record 46 of Set 3 | abepura
# Processing Record 47 of Set 3 | hays
# Processing Record 48 of Set 3 | ailuk
# Processing Record 49 of Set 3 | tver
# Processing Record 0 of Set 4 | argo
# Processing Record 1 of Set 4 | ha'il
# Processing Record 2 of Set 4 | puerto colombia
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | chikwawa
# Processing Record 5 of Set 4 | olonkinbyen
# Processing Record 6 of Set 4 | al qusiyah
# Processing Record 7 of Set 4 | la passe
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | mangrol
# Processing Record 10 of Set 4 | port blair
# Processing Record 11 of Set 4 | mukalla
# Processing Record 12 of Set 4 | kantabanji
# Processing Record 13 of Set 4 | igarka
# Processing Record 14 of Set 4 | dudinka
# Processing Record 15 of Set 4 | polyarnyy
# Processing Record 16 of Set 4 | oriximina
# Processing Record 17 of Set 4 | ulsteinvik
# Processing Record 18 of Set 4 | wolnzach
# Processing Record 19 of Set 4 | jogindarnagar
# Processing Record 20 of Set 4 | colonia
# Processing Record 21 of Set 4 | buckeye
# Processing Record 22 of Set 4 | funadhoo
# Processing Record 23 of Set 4 | tongliao
# Processing Record 24 of Set 4 | mount pearl
# Processing Record 25 of Set 4 | qaqortoq
# Processing Record 26 of Set 4 | coari
# Processing Record 27 of Set 4 | kapuskasing
# Processing Record 28 of Set 4 | vadso
# Processing Record 29 of Set 4 | al jawf
# Processing Record 30 of Set 4 | aykhal
# Processing Record 31 of Set 4 | taoudenni
# Processing Record 32 of Set 4 | saudarkrokur
# Processing Record 33 of Set 4 | vallenar
# Processing Record 34 of Set 4 | cadale
# Processing Record 35 of Set 4 | saint-joseph
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | reyes
# Processing Record 38 of Set 4 | dokkum
# Processing Record 39 of Set 4 | howard springs
# Processing Record 40 of Set 4 | feodosiya
# Processing Record 41 of Set 4 | arteche
# Processing Record 42 of Set 4 | el calafate
# Processing Record 43 of Set 4 | le port
# Processing Record 44 of Set 4 | huinan
# Processing Record 45 of Set 4 | tekeli
# Processing Record 46 of Set 4 | tortosa
# Processing Record 47 of Set 4 | codajas
# Processing Record 48 of Set 4 | lembar
# City not found. Skipping...
# Processing Record 49 of Set 4 | ulaangom
# Processing Record 0 of Set 5 | ola
# Processing Record 1 of Set 5 | ust'-kulom
# Processing Record 2 of Set 5 | usinsk
# Processing Record 3 of Set 5 | erdenet
# Processing Record 4 of Set 5 | gardnerville ranchos
# Processing Record 5 of Set 5 | morant bay
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | bay harbor
# Processing Record 8 of Set 5 | iquique
# Processing Record 9 of Set 5 | grants pass
# Processing Record 10 of Set 5 | carutapera
# Processing Record 11 of Set 5 | muynoq
# Processing Record 12 of Set 5 | peniche
# Processing Record 13 of Set 5 | maxixe
# Processing Record 14 of Set 5 | selfoss
# Processing Record 15 of Set 5 | saint-philippe
# Processing Record 16 of Set 5 | winnemucca
# Processing Record 17 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 18 of Set 5 | inarajan village
# Processing Record 19 of Set 5 | crane
# Processing Record 20 of Set 5 | stjordalshalsen
# Processing Record 21 of Set 5 | chonchi
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | port-cartier
# Processing Record 24 of Set 5 | vytegra
# Processing Record 25 of Set 5 | zavetnoye
# Processing Record 26 of Set 5 | estreito
# Processing Record 27 of Set 5 | mugia
# Processing Record 28 of Set 5 | sainte-suzanne
# Processing Record 29 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 5 | sao paulo de olivenca
# Processing Record 31 of Set 5 | gereida
# Processing Record 32 of Set 5 | primorsk
# Processing Record 33 of Set 5 | namtsy
# Processing Record 34 of Set 5 | fale old settlement
# Processing Record 35 of Set 5 | kapa'a
# Processing Record 36 of Set 5 | laojunmiao
# Processing Record 37 of Set 5 | inirida
# Processing Record 38 of Set 5 | boone
# Processing Record 39 of Set 5 | enewetak
# Processing Record 40 of Set 5 | lagos
# Processing Record 41 of Set 5 | belmonte
# Processing Record 42 of Set 5 | wailua homesteads
# Processing Record 43 of Set 5 | coquimbo
# Processing Record 44 of Set 5 | panaba
# Processing Record 45 of Set 5 | neiafu
# Processing Record 46 of Set 5 | pimentel
# Processing Record 47 of Set 5 | nago
# Processing Record 48 of Set 5 | tazovsky
# Processing Record 49 of Set 5 | armacao de buzios
# Processing Record 0 of Set 6 | kuqa
# Processing Record 1 of Set 6 | xapuri
# Processing Record 2 of Set 6 | gravata
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | egilsstadir
# Processing Record 5 of Set 6 | nguigmi
# Processing Record 6 of Set 6 | howrah
# Processing Record 7 of Set 6 | flin flon
# Processing Record 8 of Set 6 | al bayda'
# Processing Record 9 of Set 6 | srivardhan
# Processing Record 10 of Set 6 | princeville
# Processing Record 11 of Set 6 | ayr
# Processing Record 12 of Set 6 | cill airne
# Processing Record 13 of Set 6 | mandalgovi
# Processing Record 14 of Set 6 | la union
# Processing Record 15 of Set 6 | humaita
# Processing Record 16 of Set 6 | acajutla
# Processing Record 17 of Set 6 | keflavik
# Processing Record 18 of Set 6 | tari
# Processing Record 19 of Set 6 | sai kung
# Processing Record 20 of Set 6 | kankaanpaa
# Processing Record 21 of Set 6 | tazacorte
# Processing Record 22 of Set 6 | pazaryeri
# Processing Record 23 of Set 6 | gorontalo
# Processing Record 24 of Set 6 | kirakira
# Processing Record 25 of Set 6 | kununurra
# Processing Record 26 of Set 6 | saurimo
# Processing Record 27 of Set 6 | manokwari
# Processing Record 28 of Set 6 | ghat
# Processing Record 29 of Set 6 | riverton
# Processing Record 30 of Set 6 | mildura
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | pacific grove
# Processing Record 33 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 34 of Set 6 | port macquarie
# Processing Record 35 of Set 6 | vic-en-bigorre
# Processing Record 36 of Set 6 | kiruna
# Processing Record 37 of Set 6 | santiago juxtlahuaca
# Processing Record 38 of Set 6 | qapqal
# City not found. Skipping...
# Processing Record 39 of Set 6 | beitbridge
# Processing Record 40 of Set 6 | talara
# Processing Record 41 of Set 6 | afaahiti
# Processing Record 42 of Set 6 | el ksour
# Processing Record 43 of Set 6 | chamba
# Processing Record 44 of Set 6 | swakopmund
# Processing Record 45 of Set 6 | zhigulevsk
# Processing Record 46 of Set 6 | sitka
# Processing Record 47 of Set 6 | el fasher
# Processing Record 48 of Set 6 | tofol
# Processing Record 49 of Set 6 | sigli
# Processing Record 0 of Set 7 | praia da vitoria
# Processing Record 1 of Set 7 | touros
# Processing Record 2 of Set 7 | vilyuchinsk
# Processing Record 3 of Set 7 | chiredzi
# Processing Record 4 of Set 7 | roma
# Processing Record 5 of Set 7 | savave village
# City not found. Skipping...
# Processing Record 6 of Set 7 | port douglas
# Processing Record 7 of Set 7 | lompoc
# Processing Record 8 of Set 7 | weno
# Processing Record 9 of Set 7 | horta
# Processing Record 10 of Set 7 | cestos city
# Processing Record 11 of Set 7 | greymouth
# Processing Record 12 of Set 7 | mana
# Processing Record 13 of Set 7 | estevan
# Processing Record 14 of Set 7 | riacho de santana
# Processing Record 15 of Set 7 | at taj
# Processing Record 16 of Set 7 | wittstock
# Processing Record 17 of Set 7 | fortuna
# Processing Record 18 of Set 7 | talisay
# Processing Record 19 of Set 7 | myeik
# Processing Record 20 of Set 7 | nagqu
# Processing Record 21 of Set 7 | tura
# Processing Record 22 of Set 7 | port alfred
# Processing Record 23 of Set 7 | holualoa
# Processing Record 24 of Set 7 | kaset sombun
# Processing Record 25 of Set 7 | conde
# Processing Record 26 of Set 7 | ijebu-igbo
# Processing Record 27 of Set 7 | aginskoye
# Processing Record 28 of Set 7 | santiago
# Processing Record 29 of Set 7 | jalai nur
# Processing Record 30 of Set 7 | buta
# Processing Record 31 of Set 7 | loukhi
# Processing Record 32 of Set 7 | tshabong
# Processing Record 33 of Set 7 | palu
# Processing Record 34 of Set 7 | ixtapa
# Processing Record 35 of Set 7 | mingguang
# Processing Record 36 of Set 7 | los andes
# Processing Record 37 of Set 7 | smithers
# Processing Record 38 of Set 7 | guiuan
# Processing Record 39 of Set 7 | norrtalje
# Processing Record 40 of Set 7 | kill devil hills
# Processing Record 41 of Set 7 | lazaro cardenas
# Processing Record 42 of Set 7 | epworth
# Processing Record 43 of Set 7 | peace river
# Processing Record 44 of Set 7 | hilo
# Processing Record 45 of Set 7 | tual
# Processing Record 46 of Set 7 | rosetta
# Processing Record 47 of Set 7 | kwekwe
# Processing Record 48 of Set 7 | uacu cungo
# Processing Record 49 of Set 7 | margate
# Processing Record 0 of Set 8 | orchomenos
# Processing Record 1 of Set 8 | fontanelas
# Processing Record 2 of Set 8 | sumbawa besar
# Processing Record 3 of Set 8 | luanco
# Processing Record 4 of Set 8 | arafat
# Processing Record 5 of Set 8 | sunne
# Processing Record 6 of Set 8 | sinop
# Processing Record 7 of Set 8 | shimoda
# Processing Record 8 of Set 8 | miarinarivo
# City not found. Skipping...
# Processing Record 9 of Set 8 | roquebrune-cap-martin
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | kolonia
# Processing Record 12 of Set 8 | cascais
# Processing Record 13 of Set 8 | barras
# Processing Record 14 of Set 8 | borongan
# Processing Record 15 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 16 of Set 8 | ca mau
# Processing Record 17 of Set 8 | nouadhibou
# Processing Record 18 of Set 8 | bunia
# Processing Record 19 of Set 8 | shihezi
# Processing Record 20 of Set 8 | porto velho
# Processing Record 21 of Set 8 | sant lluis
# Processing Record 22 of Set 8 | lashio
# Processing Record 23 of Set 8 | kiiminki
# Processing Record 24 of Set 8 | patacamaya
# Processing Record 25 of Set 8 | chimoio
# Processing Record 26 of Set 8 | moapa valley
# Processing Record 27 of Set 8 | oroqen zizhiqi
# Processing Record 28 of Set 8 | gadzhiyevo
# Processing Record 29 of Set 8 | shaowu
# Processing Record 30 of Set 8 | houghton
# Processing Record 31 of Set 8 | cambria
# Processing Record 32 of Set 8 | chortkiv
# Processing Record 33 of Set 8 | raipur
# Processing Record 34 of Set 8 | seydi
# Processing Record 35 of Set 8 | veshenskaya
# Processing Record 36 of Set 8 | walvis bay
# Processing Record 37 of Set 8 | manturovo
# Processing Record 38 of Set 8 | birao
# Processing Record 39 of Set 8 | tonj
# Processing Record 40 of Set 8 | along
# Processing Record 41 of Set 8 | nushki
# Processing Record 42 of Set 8 | pizarro
# Processing Record 43 of Set 8 | ciudad lazaro cardenas
# Processing Record 44 of Set 8 | ambodifotatra
# Processing Record 45 of Set 8 | warrenpoint
# Processing Record 46 of Set 8 | skovorodino
# Processing Record 47 of Set 8 | ain leuh
# Processing Record 48 of Set 8 | musay'id
# City not found. Skipping...
# Processing Record 49 of Set 8 | shevchenkove
# Processing Record 0 of Set 9 | rosarito
# Processing Record 1 of Set 9 | kisangani
# Processing Record 2 of Set 9 | stephenville
# Processing Record 3 of Set 9 | al kharijah
# Processing Record 4 of Set 9 | simanggang
# Processing Record 5 of Set 9 | dunedin
# Processing Record 6 of Set 9 | khandyga
# Processing Record 7 of Set 9 | luderitz
# Processing Record 8 of Set 9 | svirsk
# Processing Record 9 of Set 9 | anabar
# City not found. Skipping...
# Processing Record 10 of Set 9 | susaki
# Processing Record 11 of Set 9 | rio gallegos
# Processing Record 12 of Set 9 | xinyu
# Processing Record 13 of Set 9 | apiai
# Processing Record 14 of Set 9 | kargil
# Processing Record 15 of Set 9 | sao miguel do araguaia
# Processing Record 16 of Set 9 | atmakur
# Processing Record 17 of Set 9 | shingu
# Processing Record 18 of Set 9 | sao jose da coroa grande
# Processing Record 19 of Set 9 | iranshahr
# Processing Record 20 of Set 9 | san jose del guaviare
# Processing Record 21 of Set 9 | liupanshui
# City not found. Skipping...
# Processing Record 22 of Set 9 | sisimiut
# Processing Record 23 of Set 9 | callao
# Processing Record 24 of Set 9 | lima
# Processing Record 25 of Set 9 | kristiansund
# Processing Record 26 of Set 9 | nongpoh
# Processing Record 27 of Set 9 | san julian
# Processing Record 28 of Set 9 | mitchell
# Processing Record 29 of Set 9 | nadym
# Processing Record 30 of Set 9 | malvan
# Processing Record 31 of Set 9 | remire-montjoly
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | yemva
# Processing Record 34 of Set 9 | fundulea
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | akureyri
# Processing Record 37 of Set 9 | tsiombe
# Processing Record 38 of Set 9 | tobruk
# Processing Record 39 of Set 9 | mahdia
# Processing Record 40 of Set 9 | chahar burj
# Processing Record 41 of Set 9 | ghanzi
# Processing Record 42 of Set 9 | parys
# Processing Record 43 of Set 9 | colares
# Processing Record 44 of Set 9 | tshela
# Processing Record 45 of Set 9 | escarcega
# Processing Record 46 of Set 9 | uturoa
# Processing Record 47 of Set 9 | fisterra
# Processing Record 48 of Set 9 | tanjung pandan
# Processing Record 49 of Set 9 | el daein
# City not found. Skipping...
# Processing Record 0 of Set 10 | noumea
# Processing Record 1 of Set 10 | severo-yeniseyskiy
# Processing Record 2 of Set 10 | guarapari
# Processing Record 3 of Set 10 | gizo
# Processing Record 4 of Set 10 | lawas
# Processing Record 5 of Set 10 | piti village
# Processing Record 6 of Set 10 | colon
# Processing Record 7 of Set 10 | meadow lakes
# Processing Record 8 of Set 10 | mount sterling
# Processing Record 9 of Set 10 | diego martin
# Processing Record 10 of Set 10 | dali
# Processing Record 11 of Set 10 | sao jose do campestre
# Processing Record 12 of Set 10 | barra dos coqueiros
# Processing Record 13 of Set 10 | tutong
# Processing Record 14 of Set 10 | tahe
# Processing Record 15 of Set 10 | vorkuta
# Processing Record 16 of Set 10 | dryden
# Processing Record 17 of Set 10 | san antonio de pale
# Processing Record 18 of Set 10 | extrema
# Processing Record 19 of Set 10 | ust'-barguzin
# Processing Record 20 of Set 10 | berezovyy
# Processing Record 21 of Set 10 | strathmore
# Processing Record 22 of Set 10 | lagoa
# Processing Record 23 of Set 10 | bamor kalan
# Processing Record 24 of Set 10 | kingston
# Processing Record 25 of Set 10 | ilha de mocambique
# Processing Record 26 of Set 10 | okoneshnikovo
# Processing Record 27 of Set 10 | nevada
# Processing Record 28 of Set 10 | miandrivazo
# Processing Record 29 of Set 10 | longido
# Processing Record 30 of Set 10 | rio grande
# Processing Record 31 of Set 10 | tvrdosin
# Processing Record 32 of Set 10 | krasnopavlivka
# Processing Record 33 of Set 10 | sinnar
# Processing Record 34 of Set 10 | queenstown
# Processing Record 35 of Set 10 | jiujiang
# Processing Record 36 of Set 10 | baharly
# Processing Record 37 of Set 10 | olinda
# Processing Record 38 of Set 10 | duncan
# Processing Record 39 of Set 10 | turbat
# Processing Record 40 of Set 10 | la junta
# Processing Record 41 of Set 10 | ejutla de crespo
# Processing Record 42 of Set 10 | san andres
# Processing Record 43 of Set 10 | siwa oasis
# Processing Record 44 of Set 10 | hanzhong
# Processing Record 45 of Set 10 | adh dhayd
# Processing Record 46 of Set 10 | vilhena
# Processing Record 47 of Set 10 | tadine
# Processing Record 48 of Set 10 | sur
# Processing Record 49 of Set 10 | kanigiri
# Processing Record 0 of Set 11 | kruisfontein
# Processing Record 1 of Set 11 | vyshniy volochek
# Processing Record 2 of Set 11 | tateyama
# Processing Record 3 of Set 11 | thohoyandou
# Processing Record 4 of Set 11 | uyovu
# Processing Record 5 of Set 11 | mozarlandia
# Processing Record 6 of Set 11 | vernon
# Processing Record 7 of Set 11 | eldorado at santa fe
# Processing Record 8 of Set 11 | boden
# Processing Record 9 of Set 11 | hadibu
# Processing Record 10 of Set 11 | guiberoua
# Processing Record 11 of Set 11 | puerto deseado
# Processing Record 12 of Set 11 | rongelap
# Processing Record 13 of Set 11 | ushtobe
# Processing Record 14 of Set 11 | beyneu
# Processing Record 15 of Set 11 | okhotsk
# Processing Record 16 of Set 11 | slapanice
# Processing Record 17 of Set 11 | pasighat
# Processing Record 18 of Set 11 | kimbe
# Processing Record 19 of Set 11 | guerrero negro
# Processing Record 20 of Set 11 | p'ot'i
# Processing Record 21 of Set 11 | rawlins
# Processing Record 22 of Set 11 | mingshui
# Processing Record 23 of Set 11 | flying fish cove
# Processing Record 24 of Set 11 | fort mcmurray
# Processing Record 25 of Set 11 | dunda
# Processing Record 26 of Set 11 | chibougamau
# Processing Record 27 of Set 11 | bikenibeu village
# Processing Record 28 of Set 11 | guiratinga
# Processing Record 29 of Set 11 | kayangel
# Processing Record 30 of Set 11 | pisco
# Processing Record 31 of Set 11 | urzhar
# Processing Record 32 of Set 11 | ostashkov
# Processing Record 33 of Set 11 | naze
# Processing Record 34 of Set 11 | la sarre
# Processing Record 35 of Set 11 | tocopilla
# Processing Record 36 of Set 11 | arraial do cabo
# Processing Record 37 of Set 11 | stettler
# Processing Record 38 of Set 11 | kirensk
# Processing Record 39 of Set 11 | castel di sangro
# Processing Record 40 of Set 11 | seosan
# Processing Record 41 of Set 11 | hue
# Processing Record 42 of Set 11 | yuni
# Processing Record 43 of Set 11 | qashyr
# Processing Record 44 of Set 11 | mogocha
# Processing Record 45 of Set 11 | airway heights
# Processing Record 46 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 47 of Set 11 | leirvik
# Processing Record 48 of Set 11 | bodo
# Processing Record 49 of Set 11 | wewak
# Processing Record 0 of Set 12 | recani
# Processing Record 1 of Set 12 | bac lieu
# Processing Record 2 of Set 12 | al fqih ben calah
# Processing Record 3 of Set 12 | pingxiang
# Processing Record 4 of Set 12 | pierre
# Processing Record 5 of Set 12 | tawau
# Processing Record 6 of Set 12 | kittila
# Processing Record 7 of Set 12 | errachidia
# Processing Record 8 of Set 12 | swift current
# Processing Record 9 of Set 12 | clusone
# Processing Record 10 of Set 12 | la mira
# Processing Record 11 of Set 12 | inhambane
# Processing Record 12 of Set 12 | banff
# Processing Record 13 of Set 12 | dobryanka
# Processing Record 14 of Set 12 | gurupi
# Processing Record 15 of Set 12 | atamanovka
# Processing Record 16 of Set 12 | patterson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0                 new norfolk -42.7826  147.0587     50.92        68
# 1           port-aux-francais -49.3500   70.2167     42.33        93
# 2                   kavaratti  10.5669   72.6420     84.96        56
# 3                      albany  42.6001  -73.9662     64.17        31
# 4    petropavlovsk-kamchatsky  53.0452  158.6483     30.79       100
# ..                        ...      ...       ...       ...       ...
# 544                     banff  51.1762 -115.5698     46.78        76
# 545                 dobryanka  58.4619   56.4165     39.02        60
# 546                    gurupi -11.7292  -49.0686     90.39        40
# 547                atamanovka  51.9300  113.6300     34.23        37
# 548                 patterson  37.4716 -121.1297     63.99        63
#
#      Cloudiness  Wind Speed Country        Date
# 0            97        1.01      AU  1683653778
# 1            96       20.07      TF  1683653783
# 2            19        5.97      IN  1683653784
# 3           100        1.99      US  1683653722
# 4            75        4.47      RU  1683653784
# ..          ...         ...     ...         ...
# 544          99        3.44      CA  1683653932
# 545           4        4.54      RU  1683653933
# 546          70        3.13      BR  1683653693
# 547           0        2.71      RU  1683653933
# 548         100        6.71      US  1683653933
#
# [549 rows x 9 columns]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          549
# Lat           549
# Lng           549
# Max Temp      549
# Humidity      549
# Cloudiness    549
# Wind Speed    549
# Country       549
# Date          549
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0               new norfolk -42.7826  147.0587     50.92        68
# 1         port-aux-francais -49.3500   70.2167     42.33        93
# 2                 kavaratti  10.5669   72.6420     84.96        56
# 3                    albany  42.6001  -73.9662     64.17        31
# 4  petropavlovsk-kamchatsky  53.0452  158.6483     30.79       100
#
#    Cloudiness  Wind Speed Country        Date
# 0          97        1.01      AU  1683653778
# 1          96       20.07      TF  1683653783
# 2          19        5.97      IN  1683653784
# 3         100        1.99      US  1683653722
# 4          75        4.47      RU  1683653784

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                     new norfolk -42.7826  147.0587     50.92        68
# 1               port-aux-francais -49.3500   70.2167     42.33        93
# 2                       kavaratti  10.5669   72.6420     84.96        56
# 3                          albany  42.6001  -73.9662     64.17        31
# 4        petropavlovsk-kamchatsky  53.0452  158.6483     30.79       100
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                97        1.01      AU  1683653778
# 1                96       20.07      TF  1683653783
# 2                19        5.97      IN  1683653784
# 3               100        1.99      US  1683653722
# 4                75        4.47      RU  1683653784

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_v_temp = city_data_df.plot.scatter(x='Lat', y='Max Temp', s=10, colormap='viridis',grid=True)
# Incorporate the other graph properties
lat_v_temp.set_xlabel('Latitude')
lat_v_temp.set_ylabel('Temperature (F)')
lat_v_temp.set_title('City Latitude vs. Temperature (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_v_humidity = city_data_df.plot.scatter(x='Lat', y='Humidity', s=10, colormap='viridis', grid=True)

# Incorporate the other graph properties
lat_v_humidity.set_xlabel('Latitude')
lat_v_humidity.set_ylabel('Humidity (%)')
lat_v_humidity.set_title('City Latitude vs. Humidity (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_v_cloudiness = city_data_df.plot.scatter(x='Lat', y='Cloudiness', s=10, colormap='viridis', grid=True)


# Incorporate the other graph properties
lat_v_cloudiness.set_xlabel('Latitude')
lat_v_cloudiness.set_ylabel('Cloudiness')
lat_v_cloudiness.set_title('City Latitude vs. Cloudiness (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
lat_v_wind_speed = city_data_df.plot.scatter(x='Lat', y='Wind Speed', s=10, colormap='viridis', grid=True)

# Incorporate the other graph properties
lat_v_wind_speed.set_xlabel('Latitude')
lat_v_wind_speed.set_ylabel('Wind Speed')
lat_v_wind_speed.set_title('City Latitude vs. Wind Speed (2023-05-05)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#y = (m*x) + b

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_match = city_data_df['Lat']>=0
northern_hemi_df = city_data_df.loc[northern_hemi_match][['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Country','Date']].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                 kavaratti  10.5669   72.6420     84.96        56
# 1                    albany  42.6001  -73.9662     64.17        31
# 2  petropavlovsk-kamchatsky  53.0452  158.6483     30.79       100
# 3               kailua-kona  19.6406 -155.9956     75.16        85
# 4                   susuman  62.7833  148.1667     27.00        95
#
#    Cloudiness  Wind Speed Country        Date
# 0          19        5.97      IN  1683653784
# 1         100        1.99      US  1683653722
# 2          75        4.47      RU  1683653784
# 3          40        6.91      US  1683653785
# 4          99        3.53      RU  1683653785

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_match = city_data_df['Lat']<0
southern_hemi_df = city_data_df.loc[southern_hemi_match][['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Country','Date']].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        new norfolk -42.7826  147.0587     50.92        68          97
# 1  port-aux-francais -49.3500   70.2167     42.33        93          96
# 2           waitangi -43.9535 -176.5597     60.82        95         100
# 3             avarua -21.2078 -159.7750     77.05        88          75
# 4           hermanus -34.4187   19.2345     55.80        73          62
#
#    Wind Speed Country        Date
# 0        1.01      AU  1683653778
# 1       20.07      TF  1683653783
# 2       11.01      NZ  1683653785
# 3       20.71      CK  1683653785
# 4        4.88      ZA  1683653786

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
temperature_northern = northern_hemi_df['Max Temp']

northern_temp_slope, northern_temp_int, northern_temp_r, northern_temp_p, northern_temp_std_err, = linregress(latitude_northern, temperature_northern)
northern_temp_fit = (northern_temp_slope*latitude_northern) + northern_temp_int

northern_temp_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Max Temp', s=10, grid=True, colormap='viridis')
northern_temp_scatter_plot.set_ylabel('Temperature (F)')
northern_temp_scatter_plot.set_xlabel('Latitude')
northern_temp_scatter_plot.set_title('Northern Hemisphere: Temperature vs. Latitude')
plt.plot(latitude_northern, northern_temp_fit, '--', color='r')

# %%
# Linear regression on Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
temperature_southern = southern_hemi_df['Max Temp']

southern_temp_slope, southern_temp_int, southern_temp_r, southern_temp_p, southern_temp_std_err, = linregress(latitude_southern, temperature_southern)
southern_temp_fit = (southern_temp_slope*latitude_southern) + southern_temp_int

southern_temp_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Max Temp', s=10, grid=True, colormap='viridis')
southern_temp_scatter_plot.set_ylabel('Temperature (F)')
southern_temp_scatter_plot.set_xlabel('Latitude')
southern_temp_scatter_plot.set_title('Southern Hemisphere: Temperature vs. Latitude')
plt.plot(latitude_southern, southern_temp_fit, '--', color='r')

# %% [markdown]
# ### Analysis:
# Looking at the two figures, it appears that has one gets closer to the equator, temperatures rise. In the northern hemisphere as latitudes get higher, temperatures go down. In the southern hemisphere, the furtehr south you go (latitudes get further away from zero), the lower the temperatures. For locations near the equator (latitude of zero), temperatures are around 80-90 degrees farenheit, in general. The pearson correlation coefficients for latitude vs. temperature in both the northern and southern hemispheres have absolute values around .8, suggesting a strong relationship between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
humidity_northern = northern_hemi_df['Humidity']

northern_humidity_slope, northern_humidity_int, northern_humidity_r, northern_humidity_p, northern_humidity_std_err, = linregress(latitude_northern, humidity_northern)
northern_humidity_fit = (northern_humidity_slope*latitude_northern) + northern_humidity_int

northern_humidity_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Humidity', s=10, grid=True, colormap='viridis')
northern_humidity_scatter_plot.set_ylabel('Humidity (%)')
northern_humidity_scatter_plot.set_xlabel('Latitude')
northern_humidity_scatter_plot.set_title('Northern Hemisphere: Humidity vs. Latitude')
plt.plot(latitude_northern, northern_humidity_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
humidity_southern = southern_hemi_df['Humidity']

southern_humidity_slope, southern_humidity_int, southern_humidity_r, southern_humidity_p, southern_humidity_std_err, = linregress(latitude_southern, humidity_southern)
southern_humidity_fit = (southern_humidity_slope*latitude_southern) + southern_humidity_int

southern_humidity_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Humidity', s=10, grid=True, colormap='viridis')
southern_humidity_scatter_plot.set_ylabel('Humidity (%)')
southern_humidity_scatter_plot.set_xlabel('Latitude')
southern_humidity_scatter_plot.set_title('Southern Hemisphere: Humidity vs. Latitude')
plt.plot(latitude_southern, southern_humidity_fit, '--', color='r')

# %% [markdown]
# ### Analysis
# In both the southern and northern hemispheres there is not a strong relationship between latitude and humidity. For example, in places with latitudes between 30 and 40 degrees south, we see humidity values at close to 0 and at 100%. The linear regression in the southern hemisphere plot is almost flat, while the linear regression in the northern hemisphere is slightly more angled, showing a very slight positive relationship between latitude and humidity in the northern hemisphere. In contrast to the relationship between latitude and temperature, the pearson correlation coefficients for both the northern and southern hemispheres (humidity vs. latitude) are below .2, and indicate weak relationships.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
cloudiness_northern = northern_hemi_df['Cloudiness']

northern_cloudiness_slope, northern_cloudiness_int, northern_cloudiness_r, northern_cloudiness_p, northern_cloudiness_std_err, = linregress(latitude_northern, cloudiness_northern)
northern_cloudiness_fit = (northern_cloudiness_slope*latitude_northern) + northern_cloudiness_int

northern_cloudiness_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Cloudiness', s=10, grid=True, colormap='viridis')
northern_cloudiness_scatter_plot.set_ylabel('Cloudiness')
northern_cloudiness_scatter_plot.set_xlabel('Latitude')
northern_cloudiness_scatter_plot.set_title('Northern Hemisphere: Cloudiness vs. Latitude')
plt.plot(latitude_northern, northern_cloudiness_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
cloudiness_southern = southern_hemi_df['Cloudiness']

southern_cloudiness_slope, southern_cloudiness_int, southern_cloudiness_r, southern_cloudiness_p, southern_cloudiness_std_err, = linregress(latitude_southern, cloudiness_southern)
southern_cloudiness_fit = (southern_cloudiness_slope*latitude_southern) + southern_cloudiness_int

southern_cloudiness_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Cloudiness', s=10, grid=True, colormap='viridis')
southern_cloudiness_scatter_plot.set_ylabel('Cloudiness')
southern_cloudiness_scatter_plot.set_xlabel('Latitude')
southern_cloudiness_scatter_plot.set_title('Southern Hemisphere: Cloudiness vs. Latitude')
plt.plot(latitude_southern, southern_cloudiness_fit, '--', color='r')

# %%
# Out:
# 0.09312947952916632

# %% [markdown]
# **Analysis**
# In both the northern and southern hemispheres there appear to be slightly positive relationships between latitude and cloudiness. In the northern hemisphere going further north (further from the equator) shows a slight increase in the level of cloudiness. In the southern hemisphere the relationship is that as you go further north (closer to the equator) cloudiness increases. In both instances the pearson correlation coefficient has an absolute value of less than .2, and is thus the relationship between the two variables very weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
latitude_northern = northern_hemi_df['Lat']
wind_speed_northern = northern_hemi_df['Wind Speed']

northern_wind_speed_slope, northern_wind_speed_int, northern_wind_speed_r, northern_wind_speed_p, northern_wind_speed_std_err, = linregress(latitude_northern, wind_speed_northern)
northern_wind_speed_fit = (northern_wind_speed_slope*latitude_northern) + northern_wind_speed_int

northern_wind_speed_scatter_plot = northern_hemi_df.plot.scatter('Lat', 'Wind Speed', s=10, grid=True, colormap='viridis')
northern_wind_speed_scatter_plot.set_ylabel('Wind speed')
northern_wind_speed_scatter_plot.set_xlabel('Latitude')
northern_wind_speed_scatter_plot.set_title('Northern Hemisphere: Wind Speed vs. Latitude')
plt.plot(latitude_northern, northern_wind_speed_fit, '--', color='r')

# %%
# Southern Hemisphere
latitude_southern = southern_hemi_df['Lat']
wind_speed_southern = southern_hemi_df['Wind Speed']

southern_wind_speed_slope, southern_wind_speed_int, southern_wind_speed_r, southern_wind_speed_p, southern_wind_speed_std_err, = linregress(latitude_southern, wind_speed_southern)
southern_wind_speed_fit = (southern_wind_speed_slope*latitude_southern) + southern_wind_speed_int

southern_wind_speed_scatter_plot = southern_hemi_df.plot.scatter('Lat', 'Wind Speed', s=10, grid=True, colormap='viridis')
southern_wind_speed_scatter_plot.set_ylabel('Wind speed')
southern_wind_speed_scatter_plot.set_xlabel('Latitude')
southern_wind_speed_scatter_plot.set_title('Southern Hemisphere: Wind Speed vs. Latitude')
plt.plot(latitude_southern, southern_wind_speed_fit, '--', color='r')

# %% [markdown]
# **Analysis**
# In both the northern and southern hemispheres there appear to be slightly negative relationships between latitude and wind speed. In the northern hemisphere going further north (further from the equator) shows a slight decrease in the wind speed. In the southern hemisphere the relationship is that as you go further north (closer to the equator) wind speed increases. In both instances the pearson correlation coefficient has an absolute value of less than .2, and is thus the relationship between the two variables very weak.
